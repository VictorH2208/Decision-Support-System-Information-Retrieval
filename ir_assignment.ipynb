# %% [markdown]
# # Assignment 1: IR

# %% [markdown]
# ## Preparations
# * Put all your imports, and path constants in the next cells

# %%
# !pip install whoosh
# !pip install pytrec_eval
# !pip install wget
# !pip install transformers
# !pip install sentence_transformers

# %%
import wget
wget.download("https://github.com/MIE451-1513-2023/course-datasets/raw/main/government.zip", "government.zip")

# %%
# !unzip government.zip

# %%
# imports
# Put all your imports here
from whoosh import index, writing
from whoosh.fields import Schema, TEXT, KEYWORD, ID, STORED
from whoosh.analysis import *
from whoosh.qparser import QueryParser
import os.path
from pathlib import Path
import tempfile
import subprocess
import pytrec_eval
import wget
import abc
from abc import abstractmethod
from whoosh.analysis import Filter
import nltk
from nltk.stem import *
from whoosh import qparser
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
class IRSystem(metaclass=abc.ABCMeta):
    """
    Abstract class which is inherited by other IR system
    """

    def __init__(self, data_dir):
        # DON'T change the following names,topic_file, qrels_file, document_dir, file_list
        self.topic_file = os.path.join(data_dir, "gov.topics")
        self.qrels_file = os.path.join(data_dir, "gov.qrels")
        self.document_dir = os.path.join(data_dir, "documents")
        self.file_list = [str(filePath) for filePath in Path(self.document_dir).glob("**/*") if filePath.is_file()]

        self.create_index()
        self.create_parser_searcher()

    @abstractmethod
    def create_index(self):
        pass

    @abstractmethod
    def add_files(self):
        pass

    @abstractmethod
    def create_parser_searcher(self):
        pass

    @abstractmethod
    def perform_search(self, topic_phrase):
        pass

    @staticmethod
    def post_process_score(score):
        return score

    @staticmethod
    def print_trec_eval_result(results):

        if not results:
            print('empty results')
            return

        def print_line(name, scope, num):
            print('{:25s}{:8s}{:.4f}'.format(name, scope, num))

        for query_id, query_measures in results.items():
            for measure, value in query_measures.items():
                if measure == "runid":
                    continue
                print_line(measure, query_id, value)

        for measure in query_measures.keys():
            if measure == "runid":
                continue
            print_line(
                measure,
                'all',
                pytrec_eval.compute_aggregated_measure(
                    measure,
                    [query_measures[measure]
                    for query_measures in results.values()]))


    def score(self,docnum,topic_results, topic_phrase):
        return topic_results.score(docnum)


    def print_rel_name(self, q_id):
        with open(self.topic_file, "r") as tf:
            topics = tf.read().splitlines()
        for topic in topics:
            topic_id, topic_phrase = tuple(topic.split(" ", 1))
            if topic_id == q_id:
                print("---------------------------Topic_id and Topic_phrase----------------------------------")
                print(topic_id, topic_phrase)
                 # get search result
                topic_results = self.perform_search(topic_phrase)
                print("---------------------------Return documents----------------------------------")
                for (docnum, result) in enumerate(topic_results):
                    score = self.score(docnum, topic_results, topic_phrase)
                    score = self.post_process_score(score)
                    print("%s Q0 %s %d %lf test" % (topic_id, os.path.basename(result["file_path"]), docnum, score))
                print("---------------------------Relevant documents----------------------------------")
                with open(self.qrels_file, 'r') as f_qrel:
                    qrels = f_qrel.readlines()
                    for i in qrels:
                        qid, _, doc, rel = i.rstrip().split(" ")
                        if qid == q_id and rel == "1":
                            print(i.rstrip())

    def py_trec_eval(self):

        self.create_parser_searcher()
        # Load topic file - a list of topics(search phrases) used for evalutation
        with open(self.topic_file, "r") as tf:
            topics = tf.read().splitlines()

            # create an output file to which we'll write our results
        temp_output_file = tempfile.mkstemp()[1]
        with open(temp_output_file, "w") as outputTRECFile:
            # for each evaluated topic:
            # build a query and record the results in the file in TREC_EVAL format
            for topic in topics:
                topic_id, topic_phrase = tuple(topic.split(" ", 1))
                # get search result
                topic_results = self.perform_search(topic_phrase)
                # format the result
                for (docnum, result) in enumerate(topic_results):
                    score = self.score(docnum, topic_results, topic_phrase)
                    outputTRECFile.write(
                        "%s Q0 %s %d %lf test\n" % (topic_id, os.path.basename(result["file_path"]), docnum, score))
                    topic_with_result = topic_id


        with open(self.qrels_file, 'r') as f_qrel:
            qrel = pytrec_eval.parse_qrel(f_qrel)

        with open(temp_output_file, 'r') as f_run:
            run = pytrec_eval.parse_run(f_run)

        evaluator = pytrec_eval.RelevanceEvaluator(
            qrel, pytrec_eval.supported_measures)

        results = evaluator.evaluate(run)

        #fill results dictionary with queries that were returned 0 documents
        topic_ids = {t.split()[0] for t in topics}
        for emptyresult_topicid in topic_ids.difference(set(results.keys())):
            num_rel = float(sum(qrel[emptyresult_topicid].values()))
            if num_rel>0:
              topic_stats={measure:0.0 for measure in results[topic_with_result]}
            else:
              topic_stats={measure:1.0 for measure in results[topic_with_result]}
            topic_stats["num_rel"]=num_rel
            topic_stats["num_ret"] = 0.0
            topic_stats["num_rel_ret"] = 0.0
            topic_stats["num_q"]=1.0

            results[emptyresult_topicid] = topic_stats


        self.print_trec_eval_result(results)

# %%
# ir_sys_0 = IRSystem("lab-data")

# %%
# Dont change this! Use it as-is in your code
# This filter will run for both the index and the query
class CustomFilter(Filter):
    is_morph = True
    def __init__(self, filterFunc, *args, **kwargs):
        self.customFilter = filterFunc
        self.args = args
        self.kwargs = kwargs
    def __eq__(self):
        return (other
                and self.__class__ is other.__class__)
    def __call__(self, tokens):
        for t in tokens:
            if t.mode == 'query': # if called by query parser
                t.text = self.customFilter(t.text, *self.args, **self.kwargs)
                yield t
            else: # == 'index' if called by indexer
                t.text = self.customFilter(t.text, *self.args, **self.kwargs)
                yield t

# %% [markdown]
# ## Question 1
# Provide your text answers in the following two markdown cells

# %% [markdown]
# ### Q1 (a): Provide answer to Q1 (a) here [markdown cell]
#
# MAP: mean average precision

# %% [markdown]
# ### Q1 (b): Provide answer to Q1 (b) here [markdown cell]
#
#  MAP is a comprehensive measure that takes into account both precision and recall at various cutoffs and provides an overall measure of retrieval quality.

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Q2 (a): Write your code below

# %% [markdown]
# **1. The auto-grader will extract and use the following variables, DON'T change the their names:**
#
#       self.topic_file
#       self.qrels_file
#       self.document_dir
#       self.file_list
#       self.index_sys
#       self.query_parser
#       self.searcher
#
#
#
# **2. DON'T change the names of the already defined funtions**
# **3. DON'T change the py_trec_eval function**
# **4. DON'T change the class names including CustomFilter, IRSystem, IRQ2, IRQ3, IRQ4**
# **5. DON'T change the CustomFilter class and DON'T create any new custom filter class that is used to define Whoosh schema**

# %%
from whoosh.qparser.syntax import QueryParserError
class IRQ2(IRSystem):
    def create_index(self):
        """
        INPUT:
            None
        OUTPUT:
            None

        NOTE: Please update self.index_sys which should have type whoosh.index.FileIndex
        """

        schema = Schema(file_path = ID(stored=True),
                  file_content = TEXT(analyzer = RegexTokenizer()))
        indexDir = tempfile.mkdtemp()

        # DON't change the name of 'index_sys'
        self.index_sys = index.create_in(indexDir, schema)

    def add_files(self):
        """
        INPUT:
            None
        OUTPUT:
            None

        NOTE: Add buffer to self.index_sys
        """
        writer = writing.BufferedWriter(self.index_sys, period=None, limit=1000)
        try:
            for docNum, filePath in enumerate(self.file_list):
                with open(filePath, "r", encoding="utf-8") as f:
                    content = f.read()
                    writer.add_document(file_path = filePath, file_content = content)
        finally:
            writer.close()

    def create_parser_searcher(self):
        """
        INPUT:
            None
        OUTPUT:
            None

        NOTE: Please update self.query_parser and self.self.searcherwhich should have type whoosh.qparser.default.QueryParser and whoosh.searching.Searcher respectively
        """
         # DON't change the names of 'query_parser' and 'searcher'
        self.query_parser = QueryParser("file_content", schema=self.index_sys.schema)
        self.searcher = self.index_sys.searcher()

    def perform_search(self, topic_phrase):
        """
        INPUT:
            topic_phrase: string
        OUTPUT:
            topic_results: whoosh.searching.Results

        NOTE: Utilize self.query_parser and self.searcher to calculate the result for topic_phrase
        """
        query = self.query_parser.parse(topic_phrase)
        topic_results = self.searcher.search(query, limit=None)
        return topic_results

# %%
q2 = IRQ2("government")

# %%
q2.add_files()

# %%
q2.py_trec_eval()
# Out:
# num_q                    1       1.0000
# num_ret                  1       1.0000
# num_rel                  1       5.0000
# num_rel_ret              1       0.0000
# map                      1       0.0000
# gm_map                   1       -11.5129
# Rprec                    1       0.0000
# bpref                    1       0.0000
# recip_rank               1       0.0000
# iprec_at_recall_0.00     1       0.0000
# iprec_at_recall_0.10     1       0.0000
# iprec_at_recall_0.20     1       0.0000
# iprec_at_recall_0.30     1       0.0000
# iprec_at_recall_0.40     1       0.0000
# iprec_at_recall_0.50     1       0.0000
# iprec_at_recall_0.60     1       0.0000
# iprec_at_recall_0.70     1       0.0000
# iprec_at_recall_0.80     1       0.0000
# iprec_at_recall_0.90     1       0.0000
# iprec_at_recall_1.00     1       0.0000
# P_5                      1       0.0000
# P_10                     1       0.0000
# P_15                     1       0.0000
# P_20                     1       0.0000
# P_30                     1       0.0000
# P_100                    1       0.0000
# P_200                    1       0.0000
# P_500                    1       0.0000
# P_1000                   1       0.0000
# relstring                1       0.0000
# recall_5                 1       0.0000
# recall_10                1       0.0000
# recall_15                1       0.0000
# recall_20                1       0.0000
# recall_30                1       0.0000
# recall_100               1       0.0000
# recall_200               1       0.0000
# recall_500               1       0.0000
# recall_1000              1       0.0000
# infAP                    1       0.0000
# gm_bpref                 1       -11.5129
# Rprec_mult_0.20          1       0.0000
# Rprec_mult_0.40          1       0.0000
# Rprec_mult_0.60          1       0.0000
# Rprec_mult_0.80          1       0.0000
# Rprec_mult_1.00          1       0.0000
# Rprec_mult_1.20          1       0.0000
# Rprec_mult_1.40          1       0.0000
# Rprec_mult_1.60          1       0.0000
# Rprec_mult_1.80          1       0.0000
# Rprec_mult_2.00          1       0.0000
# utility                  1       
# map_cut_10               2       0.0000
# map_cut_15               2       0.0000
# map_cut_20               2       0.0000
# map_cut_30               2       0.0000
# map_cut_100              2       0.0000
# map_cut_200              2       0.0000
# map_cut_500              2       0.0000
# map_cut_1000             2       0.0000
# relative_P_5             2       0.0000
# relative_P_10            2       0.0000
# relative_P_15            2       0.0000
# relative_P_20            2       0.0000
# relative_P_30            2       0.0000
# relative_P_100           2       0.0000
# relative_P_200           2       0.0000
# relative_P_500           2       0.0000
# relative_P_1000          2       0.0000
# success_1                2       0.0000
# success_5                2       0.0000
# success_10               2       0.0000
# set_P                    2       0.0000
# set_relative_P           2       0.0000
# set_recall               2       0.0000
# set_map                  2       0.0000
# set_F                    2       0.0000
# num_nonrel_judged_ret    2       4.0000
# num_q                    6       1.0000
# num_ret                  6       5.0000
# num_rel                  6       1.0000
# num_rel_ret              6       0.0000
# map                      6       0.0000
# gm_map                   6       -11.5129
# Rprec                    6       0.0000
# bpref                    6       0.0000
# recip_rank               6       0.0000
# iprec_at_recall_0.00     6       0.0000
# iprec_at_recall_0.10     6       0.0000
# iprec_at_recall_0.20     6       0.0000
# iprec_at_recall_0.30     6       0.0000
# iprec_at_recall_0.40     6       0.0000
# iprec_at_recall_0.50     6       0.0000
# iprec_at_recall_0.60     6       0.0000
# iprec_at_recall_0.70     6       0.0000
# iprec_at_recall_0.80     6       0.0000
# iprec_at_recall_0.90     6       0.0000
# iprec_at_recall_1.00     6       0.0000
# P_5                      6       0.0000
# P_10                     6       0.0000
# P_15                     6       0.0000
# P_20                     6       0.0000
# P_30                     6       0.0000
# P_100                    6       0.0000
# P_200                    6       0.0000
# P_500                    6       0.0000
# P_1000                   6       0.0000
# relstring                6       0.0000
# recall_5                 6       0.0000
# recall_10                6       0.0000
# recall_15                6       0.0000
# recall_20                6       0.0000
# recall_30                6       0.0000
# recall_100               6       0.0000
# recall_200               6       0.0000
# recall_500               6       0.0000
# recall_1000              6       0.0000
# infAP                    6       0.0000
# gm_bpref                 6       -11.5129
# Rprec_mult_0.20          6       0.0000
# Rprec_mult_0.40          6       0.0000
# Rprec_mult_0.60          6       0.0000
# Rprec_mult_0.80          6       0.0000
# Rprec_mult_1.00          6       0.0000
# Rprec_mult_1.20          6       0.0000
# Rprec_mult_1.40          6       0.0000
# Rprec_mult_1.60          6       0.0000
# Rprec_mult_1.80          6       0.0000
# Rprec_mult_2.00          6       0.0000
# utility                  6       -5.0000
# 11pt_avg                 6       0.0000
# binG                     6       0.0000
# G                        6       0.0000
# ndcg                     6       0.0000
# ndcg_rel                 6       0.0000
# Rndcg                    6       0.0000
# ndcg_cut_5               6       0.0000
# ndcg_cut_10              6       0.0000
# ndcg_cut_15              6       0.0000
# ndcg_cut_20              6       0.0000
# ndcg_cut_30              6       0.0000
# ndcg_cut_100             6       0.0000
# ndcg_cut_200             6       0.0000
# ndcg_cut_500             6       0.0000
# ndcg_cut_1000            6       0.0000
# map_cut_5                6       0.0000
# map_cut_10               6       0.0000
# map_cut_15               6       0.0000
# map_cut_20               6       0.0000
# map_cut_30               6       0.0000
# map_cut_100              6       0.0000
# map_cut_200              6       0.0000
# map_cut_500              6       0.0000
# map_cut_1000             6       0.0000
# relative_P_5             6       0.0000
# relative_P_10            6       0.0000
# relative_P_15            6       0.0000
# relative_P_20            6       0.0000
# relative_P_30            6       0.0000
# relative_P_100           6       0.0000
# relative_P_200           6       0.0000
# relative_P_500           6       0.0000
# relative_P_1000          6       0.0000
# success_1                6       0.0000
# success_5                6       0.0000
# success_10               6       0.0000
# set_P                    6       0.0000
# set_relative_P           6       0.0000
# set_recall               6       0.0000
# set_map                  6       0.0000
# set_F                    6       0.0000
# num_nonrel_judged_ret    6       4.0000
# num_q                    9       1.0000
# num_ret                  9       2.0000
# num_rel                  9       1.0000
# num_rel_ret              9       0.0000
# map                      9       0.0000
# gm_map                   9       -11.5129
# Rprec                    9       0.0000
# bpref                    9       0.0000
# recip_rank               9       0.0000
# iprec_at_recall_0.00     9       0.0000
# iprec_at_recall_0.10     9       0.0000
# iprec_at_recall_0.20     9       0.0000
# iprec_at_recall_0.30     9       0.0000
# iprec_at_recall_0.40     9       0.0000
# iprec_at_recall_0.50     9       0.0000
# iprec_at_recall_0.60     9       0.0000
# iprec_at_recall_0.70     9       0.0000
# iprec_at_recall_0.80     9       0.0000
# iprec_at_recall_0.90     9       0.0000
# iprec_at_recall_1.00     9       0.0000
# P_5                      9       0.0000
# P_10                     9       0.0000
# P_15                     9       0.0000
# P_20                     9       0.0000
# P_30                     9       0.0000
# P_100                    9       0.0000
# P_200                    9       0.0000
# P_500                    9       0.0000
# P_1000                   9       0.0000
# relstring                9       0.0000
# recall_5                 9       0.0000
# recall_10                9       0.0000
# recall_15                9       0.0000
# recall_20                9       0.0000
# recall_30                9       0.0000
# recall_100               9       0.0000
# recall_200               9       0.0000
# recall_500               9       0.0000
# recall_1000              9       0.0000
# infAP                    9       0.0000
# gm_bpref                 9       -11.5129
# Rprec_mult_0.20          9       0.0000
# Rprec_mult_0.40          9       0.0000
# Rprec_mult_0.60          9       0.0000
# Rprec_mult_0.80          9       0.0000
# Rprec_mult_1.00          9       0.0000
# Rprec_mult_1.20          9       0.0000
# Rprec_mult_1.40          9       0.0000
# Rprec_mult_1.60          9       0.0000
# Rprec_mult_1.80          9       0.0000
# Rprec_mult_2.00          9       0.0000
# utility                  9       -2.0000
# 11pt_avg                 9       0.0000
# binG                     9       0.0000
# G                        9       0.0000
# ndcg                     9       0.0000
# ndcg_rel                 9       0.0000
# Rndcg                    9       0.0000
# ndcg_cut_5               9       0.0000
# ndcg_cut_10              9       0.0000
# ndcg_cut_15              9       0.0000
# ndcg_cut_20              9       0.0000
# ndcg_cut_30              9       0.0000
# ndcg_cut_100             9       0.0000
# ndcg_cut_200             9       0.0000
# ndcg_cut_500             9       0.0000
# ndcg_cut_1000            9       0.0000
# map_cut_5                9       0.0000
# map_cut_10               9       0.0000
# map_cut_15               9       0.0000
# map_cut_20               9       0.0000
# map_cut_30               9       0.0000
# map_cut_100              9       0.0000
# map_cut_200              9       0.0000
# map_cut_500              9       0.0000
# map_cut_1000             9       0.0000
# relative_P_5             9       0.0000
# relative_P_10            9       0.0000
# relative_P_15            9       0.0000
# relative_P_20            9       0.0000
# relative_P_30            9       0.0000
# relative_P_100           9       0.0000
# relative_P_200           9       0.0000
# relative_P_500           9       0.0000
# relative_P_1000          9       0.0000
# success_1                9       0.0000
# success_5                9       0.0000
# success_10               9       0.0000
# set_P                    9       0.0000
# set_relative_P           9       0.0000
# set_recall               9       0.0000
# set_map                  9       0.0000
# set_F                    9       0.0000
# num_nonrel_judged_ret    9       2.0000
# num_q                    18      1.0000
# num_ret                  18      17.0000
# num_rel                  18      1.0000
# num_rel_ret              18      1.0000
# map                      18      1.0000
# gm_map                   18      0.0000
# Rprec                    18      1.0000
# bpref                    18      1.0000
# recip_rank               18      1.0000
# iprec_at_recall_0.00     18      1.0000
# iprec_at_recall_0.10     18      1.0000
# iprec_at_recall_0.20     18      1.0000
# iprec_at_recall_0.30     18      1.0000
# iprec_at_recall_0.40     18      1.0000
# iprec_at_recall_0.50     18      1.0000
# iprec_at_recall_0.60     18      1.0000
# iprec_at_recall_0.70     18      1.0000
# iprec_at_recall_0.80     18      1.0000
# iprec_at_recall_0.90     18      1.0000
# iprec_at_recall_1.00     18      1.0000
# P_5                      18      0.2000
# P_10                     18      0.1000
# P_15                     18      0.0667
# P_20                     18      0.0500
# P_30                     18      0.0333
# P_100                    18      0.0100
# P_200                    18      0.0050
# P_500                    18      0.0020
# P_1000                   18      0.0010
# relstring                18      0.0000
# recall_5                 18      1.0000
# recall_10                18      1.0000
# recall_15                18      1.0000
# recall_20                18      1.0000
# recall_30                18      1.0000
# recall_100               18      1.0000
# recall_200               18      1.0000
# recall_500               18      1.0000
# recall_1000              18      1.0000
# infAP                    18      1.0000
# gm_bpref                 18      0.0000
# Rprec_mult_0.20          18      1.0000
# Rprec_mult_0.40          18      1.0000
# Rprec_mult_0.60          18      1.0000
# Rprec_mult_0.80          18      1.0000
# Rprec_mult_1.00          18      1.0000
# Rprec_mult_1.20          18      0.5000
# Rprec_mult_1.40          18      0.5000
# Rprec_mult_1.60          18      0.5000
# Rprec_mult_1.80          18      0.5000
# Rprec_mult_2.00          18      0.5000
# utility                  18      -15.0000
# 11pt_avg                 18      1.0000
# binG                     18      1.0000
# G                        18      1.0000
# ndcg                     18      1.0000
# ndcg_rel                 18      1.0000
# Rndcg                    18      1.0000
# ndcg_cut_5               18      1.0000
# ndcg_cut_10              18      1.0000
# ndcg_cut_15              18      1.0000
# ndcg_cut_20              18      1.0000
# ndcg_cut_30              18      1.0000
# ndcg_cut_100             18      1.0000
# ndcg_cut_200             18      1.0000
# ndcg_cut_500             18      1.0000
# ndcg_cut_1000            18      1.0000
# map_cut_5                18      1.0000
# map_cut_10               18      1.0000
# map_cut_15               18      1.0000
# map_cut_20               18      1.0000
# map_cut_30               18      1.0000
# map_cut_100              18      1.0000
# map_cut_200              18      1.0000
# map_cut_500              18      1.0000
# map_cut_1000             18      1.0000
# relative_P_5             18      1.0000
# relative_P_10            18      1.0000
# relative_P_15            18      1.0000
# relative_P_20            18      1.0000
# relative_P_30            18      1.0000
# relative_P_100           18      1.0000
# relative_P_200           18      1.0000
# relative_P_500           18      1.0000
# relative_P_1000          18      1.0000
# success_1                18      1.0000
# success_5                18      1.0000
# success_10               18      1.0000
# set_P                    18      0.0588
# set_relative_P           18      1.0000
# set_recall               18      1.0000
# set_map                  18      0.0588
# set_F                    18      0.1111
# num_nonrel_judged_ret    18      16.0000
# num_q                    22      1.0000
# num_ret                  22      17.0000
# num_rel                  22      1.0000
# num_rel_ret              22      1.0000
# map                      22      0.2000
# gm_map                   22      -1.6094
# Rprec                    22      0.0000
# bpref                    22      0.0000
# recip_rank               22      0.2000
# iprec_at_recall_0.00     22      0.2000
# iprec_at_recall_0.10     22      0.2000
# iprec_at_recall_0.20     22      0.2000
# iprec_at_recall_0.30     22      0.2000
# iprec_at_recall_0.40     22      0.2000
# iprec_at_recall_0.50     22      0.2000
# iprec_at_recall_0.60     22      0.2000
# iprec_at_recall_0.70     22      0.2000
# iprec_at_recall_0.80     22      0.2000
# iprec_at_recall_0.90     22      0.2000
# iprec_at_recall_1.00     22      0.2000
# P_5                      22      0.2000
# P_10                     22      0.1000
# P_15                     22      0.0667
# P_20                     22      0.0500
# P_30                     22      0.0333
# P_100                    22      0.0100
# P_200                    22      0.0050
# P_500                    22      0.0020
# P_1000                   22      0.0010
# relstring                22      0.0000
# recall_5                 22      1.0000
# recall_10                22      1.0000
# recall_15                22      1.0000
# recall_20                22      1.0000
# recall_30                22      1.0000
# recall_100               22      1.0000
# recall_200               22      1.0000
# recall_500               22      1.0000
# recall_1000              22      1.0000
# infAP                    22      0.2000
# gm_bpref                 22      -11.5129
# Rprec_mult_0.20          22      0.0000
# Rprec_mult_0.40          22      0.0000
# Rprec_mult_0.60          22      0.0000
# Rprec_mult_0.80          22      0.0000
# Rprec_mult_1.00          22      0.0000
# Rprec_mult_1.20          22      0.0000
# Rprec_mult_1.40          22      0.0000
# Rprec_mult_1.60          22      0.0000
# Rprec_mult_1.80          22      0.0000
# Rprec_mult_2.00          22      0.0000
# utility                  22      -15.0000
# 11pt_avg                 22      0.2000
# binG                     22      0.3869
# G                        22      0.3869
# ndcg                     22      0.3869
# ndcg_rel                 22      0.3869
# Rndcg                    22      0.1934
# ndcg_cut_5               22      0.3869
# ndcg_cut_10              22      0.3869
# ndcg_cut_15              22      0.3869
# ndcg_cut_20              22      0.3869
# ndcg_cut_30              22      0.3869
# ndcg_cut_100             22      0.3869
# ndcg_cut_200             22      0.3869
# ndcg_cut_500             22      0.3869
# ndcg_cut_1000            22      0.3869
# map_cut_5                22      0.2000
# map_cut_10               22      0.2000
# map_cut_15               22      0.2000
# map_cut_20               22      0.2000
# map_cut_30               22      0.2000
# map_cut_100              22      0.2000
# map_cut_200              22      0.2000
# map_cut_500              22      0.2000
# map_cut_1000             22      0.2000
# relative_P_5             22      1.0000
# relative_P_10            22      1.0000
# relative_P_15            22      1.0000
# relative_P_20            22      1.0000
# relative_P_30            22      1.0000
# relative_P_100           22      1.0000
# relative_P_200           22      1.0000
# relative_P_500           22      1.0000
# relative_P_1000          22      1.0000
# success_1                22      0.0000
# success_5                22      1.0000
# success_10               22      1.0000
# set_P                    22      0.0588
# set_relative_P           22      1.0000
# set_recall               22      1.0000
# set_map                  22      0.0588
# set_F                    22      0.1111
# num_nonrel_judged_ret    22      15.0000
# num_q                    24      1.0000
# num_ret                  24      7.0000
# num_rel                  24      1.0000
# num_rel_ret              24      1.0000
# map                      24      1.0000
# gm_map                   24      0.0000
# Rprec                    24      1.0000
# bpref                    24      1.0000
# recip_rank               24      1.0000
# iprec_at_recall_0.00     24      1.0000
# iprec_at_recall_0.10     24      1.0000
# iprec_at_recall_0.20     24      1.0000
# iprec_at_recall_0.30     24      1.0000
# iprec_at_recall_0.40     24      1.0000
# iprec_at_recall_0.50     24      1.0000
# iprec_at_recall_0.60     24      1.0000
# iprec_at_recall_0.70     24      1.0000
# iprec_at_recall_0.80     24      1.0000
# iprec_at_recall_0.90     24      1.0000
# iprec_at_recall_1.00     24      1.0000
# P_5                      24      0.2000
# P_10                     24      0.1000
# P_15                     24      0.0667
# P_20                     24      0.0500
# P_30                     24      0.0333
# P_100                    24      0.0100
# P_200                    24      0.0050
# P_500                    24      0.0020
# P_1000                   24      0.0010
# relstring                24      0.0000
# recall_5                 24      1.0000
# recall_10                24      1.0000
# recall_15                24      1.0000
# recall_20                24      1.0000
# recall_30                24      1.0000
# recall_100               24      1.0000
# recall_200               24      1.0000
# recall_500               24      1.0000
# recall_1000              24      1.0000
# infAP                    24      1.0000
# gm_bpref                 24      0.0000
# Rprec_mult_0.20          24      1.0000
# Rprec_mult_0.40          24      1.0000
# Rprec_mult_0.60          24      1.0000
# Rprec_mult_0.80          24      1.0000
# Rprec_mult_1.00          24      1.0000
# Rprec_mult_1.20          24      0.5000
# Rprec_mult_1.40          24      0.5000
# Rprec_mult_1.60          24      0.5000
# Rprec_mult_1.80          24      0.5000
# Rprec_mult_2.00          24      0.5000
# utility                  24      -5.0000
# 11pt_avg                 24      1.0000
# binG                     24      1.0000
# G                        24      1.0000
# ndcg                     24      1.0000
# ndcg_rel                 24      1.0000
# Rndcg                    24      1.0000
# ndcg_cut_5               24      1.0000
# ndcg_cut_10              24      1.0000
# ndcg_cut_15              24      1.0000
# ndcg_cut_20              24      1.0000
# ndcg_cut_30              24      1.0000
# ndcg_cut_100             24      1.0000
# ndcg_cut_200             24      1.0000
# ndcg_cut_500             24      1.0000
# ndcg_cut_1000            24      1.0000
# map_cut_5                24      1.0000
# map_cut_10               24      1.0000
# map_cut_15               24      1.0000
# map_cut_20               24      1.0000
# map_cut_30               24      1.0000
# map_cut_100              24      1.0000
# map_cut_200              24      1.0000
# map_cut_500              24      1.0000
# map_cut_1000             24      1.0000
# relative_P_5             24      1.0000
# relative_P_10            24      1.0000
# relative_P_15            24      1.0000
# relative_P_20            24      1.0000
# relative_P_30            24      1.0000
# relative_P_100           24      1.0000
# relative_P_200           24      1.0000
# relative_P_500           24      1.0000
# relative_P_1000          24      1.0000
# success_1                24      1.0000
# success_5                24      1.0000
# success_10               24      1.0000
# set_P                    24      0.1429
# set_relative_P           24      1.0000
# set_recall               24      1.0000
# set_map                  24      0.1429
# set_F                    24      0.2500
# num_nonrel_judged_ret    24      6.0000
# num_q                    26      1.0000
# num_ret                  26      25.0000
# num_rel                  26      3.0000
# num_rel_ret              26      1.0000
# map                      26      0.1111
# gm_map                   26      -2.1972
# Rprec                    26      0.3333
# bpref                    26      0.1111
# recip_rank               26      0.3333
# iprec_at_recall_0.00     26      0.3333
# iprec_at_recall_0.10     26      0.3333
# iprec_at_recall_0.20     26      0.3333
# iprec_at_recall_0.30     26      0.3333
# iprec_at_recall_0.40     26      0.0000
# iprec_at_recall_0.50     26      0.0000
# iprec_at_recall_0.60     26      0.0000
# iprec_at_recall_0.70     26      0.0000
# iprec_at_recall_0.80     26      0.0000
# iprec_at_recall_0.90     26      0.0000
# iprec_at_recall_1.00     26      0.0000
# P_5                      26      0.2000
# P_10                     26      0.1000
# P_15                     26      0.0667
# P_20                     26      0.0500
# P_30                     26      0.0333
# P_100                    26      0.0100
# P_200                    26      0.0050
# P_500                    26      0.0020
# P_1000                   26      0.0010
# relstring                26      0.0000
# recall_5                 26      0.3333
# recall_10                26      0.3333
# recall_15                26      0.3333
# recall_20                26      0.3333
# recall_30                26      0.3333
# recall_100               26      0.3333
# recall_200               26      0.3333
# recall_500               26      0.3333
# recall_1000              26      0.3333
# infAP                    26      0.1111
# gm_bpref                 26      -2.1972
# Rprec_mult_0.20          26      0.0000
# Rprec_mult_0.40          26      0.0000
# Rprec_mult_0.60          26      0.0000
# Rprec_mult_0.80          26      0.3333
# Rprec_mult_1.00          26      0.3333
# Rprec_mult_1.20          26      0.2500
# Rprec_mult_1.40          26      0.2000
# Rprec_mult_1.60          26      0.2000
# Rprec_mult_1.80          26      0.1667
# Rprec_mult_2.00          26      0.1667
# utility                  26      -23.0000
# 11pt_avg                 26      0.1212
# binG                     26      0.1667
# G                        26      0.1667
# ndcg                     26      0.2346
# ndcg_rel                 26      0.2346
# Rndcg                    26      0.2346
# ndcg_cut_5               26      0.2346
# ndcg_cut_10              26      0.2346
# ndcg_cut_15              26      0.2346
# ndcg_cut_20              26      0.2346
# ndcg_cut_30              26      0.2346
# ndcg_cut_100             26      0.2346
# ndcg_cut_200             26      0.2346
# ndcg_cut_500             26      0.2346
# ndcg_cut_1000            26      0.2346
# map_cut_5                26      0.1111
# map_cut_10               26      0.1111
# map_cut_15               26      0.1111
# map_cut_20               26      0.1111
# map_cut_30               26      0.1111
# map_cut_100              26      0.1111
# map_cut_200              26      0.1111
# map_cut_500              26      0.1111
# map_cut_1000             26      0.1111
# relative_P_5             26      0.3333
# relative_P_10            26      0.3333
# relative_P_15            26      0.3333
# relative_P_20            26      0.3333
# relative_P_30            26      0.3333
# relative_P_100           26      0.3333
# relative_P_200           26      0.3333
# relative_P_500           26      0.3333
# relative_P_1000          26      0.3333
# success_1                26      0.0000
# success_5                26      1.0000
# success_10               26      1.0000
# set_P                    26      0.0400
# set_relative_P           26      0.3333
# set_recall               26      0.3333
# set_map                  26      0.0133
# set_F                    26      0.0714
# num_nonrel_judged_ret    26      22.0000
# num_q                    28      1.0000
# num_ret                  28      22.0000
# num_rel                  28      2.0000
# num_rel_ret              28      0.0000
# map                      28      0.0000
# gm_map                   28      -11.5129
# Rprec                    28      0.0000
# bpref                    28      0.0000
# recip_rank               28      0.0000
# iprec_at_recall_0.00     28      0.0000
# iprec_at_recall_0.10     28      0.0000
# iprec_at_recall_0.20     28      0.0000
# iprec_at_recall_0.30     28      0.0000
# iprec_at_recall_0.40     28      0.0000
# iprec_at_recall_0.50     28      0.0000
# iprec_at_recall_0.60     28      0.0000
# iprec_at_recall_0.70     28      0.0000
# iprec_at_recall_0.80     28      0.0000
# iprec_at_recall_0.90     28      0.0000
# iprec_at_recall_1.00     28      0.0000
# P_5                      28      0.0000
# P_10                     28      0.0000
# P_15                     28      0.0000
# P_20                     28      0.0000
# P_30                     28      0.0000
# P_100                    28      0.0000
# P_200                    28      0.0000
# P_500                    28      0.0000
# P_1000                   28      0.0000
# relstring                28      0.0000
# recall_5                 28      0.0000
# recall_10                28      0.0000
# recall_15                28      0.0000
# recall_20                28      0.0000
# recall_30                28      0.0000
# recall_100               28      0.0000
# recall_200               28      0.0000
# recall_500               28      0.0000
# recall_1000              28      0.0000
# infAP                    28      0.0000
# gm_bpref                 28      -11.5129
# Rprec_mult_0.20          28      0.0000
# Rprec_mult_0.40          28      0.0000
# Rprec_mult_0.60          28      0.0000
# Rprec_mult_0.80          28      0.0000
# Rprec_mult_1.00          28      0.0000
# Rprec_mult_1.20          28      0.0000
# Rprec_mult_1.40          28      0.0000
# Rprec_mult_1.60          28      0.0000
# Rprec_mult_1.80          28      0.0000
# Rprec_mult_2.00          28      0.0000
# utility                  28      -22.0000
# 11pt_avg                 28      0.0000
# binG                     28      0.0000
# G                        28      0.0000
# ndcg                     28      0.0000
# ndcg_rel                 28      0.0000
# Rndcg                    28      0.0000
# ndcg_cut_5               28      0.0000
# ndcg_cut_10              28      0.0000
# ndcg_cut_15              28      0.0000
# ndcg_cut_20              28      0.0000
# ndcg_cut_30              28      0.0000
# ndcg_cut_100             28      0.0000
# ndcg_cut_200             28      0.0000
# ndcg_cut_500             28      0.0000
# ndcg_cut_1000            28      0.0000
# map_cut_5                28      0.0000
# map_cut_10               28      0.0000
# map_cut_15               28      0.0000
# map_cut_20               28      0.0000
# map_cut_30               28      0.0000
# map_cut_100              28      0.0000
# map_cut_200              28      0.0000
# map_cut_500              28      0.0000
# map_cut_1000             28      0.0000
# relative_P_5             28      0.0000
# relative_P_10            28      0.0000
# relative_P_15            28      0.0000
# relative_P_20            28      0.0000
# relative_P_30            28      0.0000
# relative_P_100           28      0.0000
# relative_P_200           28      0.0000
# relative_P_500           28      0.0000
# relative_P_1000          28      0.0000
# success_1                28      0.0000
# success_5                28      0.0000
# success_10               28      0.0000
# set_P                    28      0.0000
# set_relative_P           28      0.0000
# set_recall               28      0.0000
# set_map                  28      0.0000
# set_F                    28      0.0000
# num_nonrel_judged_ret    28      21.0000
# num_q                    32      1.0000
# num_ret                  32      12.0000
# num_rel                  32      8.0000
# num_rel_ret              32      0.0000
# map                      32      0.0000
# gm_map                   32      -11.5129
# Rprec                    32      0.0000
# bpref                    32      0.0000
# recip_rank               32      0.0000
# iprec_at_recall_0.00     32      0.0000
# iprec_at_recall_0.10     32      0.0000
# iprec_at_recall_0.20     32      0.0000
# iprec_at_recall_0.30     32      0.0000
# iprec_at_recall_0.40     32      0.0000
# iprec_at_recall_0.50     32      0.0000
# iprec_at_recall_0.60     32      0.0000
# iprec_at_recall_0.70     32      0.0000
# iprec_at_recall_0.80     32      0.0000
# iprec_at_recall_0.90     32      0.0000
# iprec_at_recall_1.00     32      0.0000
# P_5                      32      0.0000
# P_10                     32      0.0000
# P_15                     32      0.0000
# P_20                     32      0.0000
# P_30                     32      0.0000
# P_100                    32      0.0000
# P_200                    32      0.0000
# P_500                    32      0.0000
# P_1000                   32      0.0000
# relstring                32      0.0000
# recall_5                 32      0.0000
# recall_10                32      0.0000
# recall_15                32      0.0000
# recall_20                32      0.0000
# recall_30                32      0.0000
# recall_100               32      0.0000
# recall_200               32      0.0000
# recall_500               32      0.0000
# recall_1000              32      0.0000
# infAP                    32      0.0000
# gm_bpref                 32      -11.5129
# Rprec_mult_0.20          32      0.0000
# Rprec_mult_0.80          33      1.0000
# Rprec_mult_1.00          33      1.0000
# Rprec_mult_1.20          33      0.5000
# Rprec_mult_1.40          33      0.5000
# Rprec_mult_1.60          33      0.5000
# Rprec_mult_1.80          33      0.5000
# Rprec_mult_2.00          33      0.5000
# utility                  33      -27.0000
# 11pt_avg                 33      1.0000
# binG                     33      1.0000
# G                        33      1.0000
# ndcg                     33      1.0000
# ndcg_rel                 33      1.0000
# Rndcg                    33      1.0000
# ndcg_cut_5               33      1.0000
# ndcg_cut_10              33      1.0000
# ndcg_cut_15              33      1.0000
# ndcg_cut_20              33      1.0000
# ndcg_cut_30              33      1.0000
# ndcg_cut_100             33      1.0000
# ndcg_cut_200             33      1.0000
# ndcg_cut_500             33      1.0000
# ndcg_cut_1000            33      1.0000
# map_cut_5                33      1.0000
# map_cut_10               33      1.0000
# map_cut_15               33      1.0000
# map_cut_20               33      1.0000
# map_cut_30               33      1.0000
# map_cut_100              33      1.0000
# map_cut_200              33      1.0000
# map_cut_500              33      1.0000
# map_cut_1000             33      1.0000
# relative_P_5             33      1.0000
# relative_P_10            33      1.0000
# relative_P_15            33      1.0000
# relative_P_20            33      1.0000
# relative_P_30            33      1.0000
# relative_P_100           33      1.0000
# relative_P_200           33      1.0000
# relative_P_500           33      1.0000
# relative_P_1000          33      1.0000
# success_1                33      1.0000
# success_5                33      1.0000
# success_10               33      1.0000
# set_P                    33      0.0345
# set_relative_P           33      1.0000
# set_recall               33      1.0000
# set_map                  33      0.0345
# set_F                    33      0.0667
# num_nonrel_judged_ret    33      6.0000
# num_q                    36      1.0000
# num_ret                  36      11.0000
# num_rel                  36      3.0000
# num_rel_ret              36      0.0000
# map                      36      0.0000
# gm_map                   36      -11.5129
# Rprec                    36      0.0000
# bpref                    36      0.0000
# recip_rank               36      0.0000
# iprec_at_recall_0.00     36      0.0000
# iprec_at_recall_0.10     36      0.0000
# iprec_at_recall_0.20     36      0.0000
# iprec_at_recall_0.30     36      0.0000
# iprec_at_recall_0.40     36      0.0000
# iprec_at_recall_0.50     36      0.0000
# iprec_at_recall_0.60     36      0.0000
# iprec_at_recall_0.70     36      0.0000
# iprec_at_recall_0.80     36      0.0000
# iprec_at_recall_0.90     36      0.0000
# iprec_at_recall_1.00     36      0.0000
# P_5                      36      0.0000
# P_10                     36      0.0000
# P_15                     36      0.0000
# P_20                     36      0.0000
# P_30                     36      0.0000
# P_100                    36      0.0000
# P_200                    36      0.0000
# P_500                    36      0.0000
# P_1000                   36      0.0000
# relstring                36      0.0000
# recall_5                 36      0.0000
# recall_10                36      0.0000
# recall_15                36      0.0000
# recall_20                36      0.0000
# recall_30                36      0.0000
# recall_100               36      0.0000
# recall_200               36      0.0000
# recall_500               36      0.0000
# recall_1000              36      0.0000
# infAP                    36      0.0000
# gm_bpref                 36      -11.5129
# Rprec_mult_0.20          36      0.0000
# Rprec_mult_0.40          36      0.0000
# Rprec_mult_0.60          36      0.0000
# Rprec_mult_0.80          36      0.0000
# Rprec_mult_1.00          36      0.0000
# Rprec_mult_1.20          36      0.0000
# Rprec_mult_1.40          36      0.0000
# Rprec_mult_1.60          36      0.0000
# Rprec_mult_1.80          36      0.0000
# Rprec_mult_2.00          36      0.0000
# utility                  36      -11.0000
# 11pt_avg                 36      0.0000
# binG                     36      0.0000
# G                        36      0.0000
# ndcg                     36      0.0000
# ndcg_rel                 36      0.0000
# Rndcg                    36      0.0000
# ndcg_cut_5               36      0.0000
# ndcg_cut_10              36      0.0000
# ndcg_cut_15              36      0.0000
# ndcg_cut_20              36      0.0000
# ndcg_cut_30              36      0.0000
# ndcg_cut_100             36      0.0000
# ndcg_cut_200             36      0.0000
# ndcg_cut_500             36      0.0000
# ndcg_cut_1000            36      0.0000
# map_cut_5                36      0.0000
# map_cut_10               36      0.0000
# map_cut_15               36      0.0000
# map_cut_20               36      0.0000
# map_cut_30               36      0.0000
# map_cut_100              36      0.0000
# map_cut_200              36      0.0000
# map_cut_500              36      0.0000
# map_cut_1000             36      0.0000
# relative_P_5             36      0.0000
# relative_P_10            36      0.0000
# relative_P_15            36      0.0000
# relative_P_20            36      0.0000
# relative_P_30            36      0.0000
# relative_P_100           36      0.0000
# relative_P_200           36      0.0000
# relative_P_500           36      0.0000
# relative_P_1000          36      0.0000
# success_1                36      0.0000
# success_5                36      0.0000
# success_10               36      0.0000
# set_P                    36      0.0000
# set_relative_P           36      0.0000
# set_recall               36      0.0000
# set_map                  36      0.0000
# set_F                    36      0.0000
# num_nonrel_judged_ret    36      2.0000
# num_q                    43      1.0000
# num_ret                  43      1.0000
# num_rel                  43      1.0000
# num_rel_ret              43      0.0000
# map                      43      0.0000
# gm_map                   43      -11.5129
# Rprec                    43      0.0000
# bpref                    43      0.0000
# recip_rank               43      0.0000
# iprec_at_recall_0.00     43      0.0000
# iprec_at_recall_0.10     43      0.0000
# iprec_at_recall_0.20     43      0.0000
# iprec_at_recall_0.30     43      0.0000
# iprec_at_recall_0.40     43      0.0000
# iprec_at_recall_0.50     43      0.0000
# iprec_at_recall_0.60     43      0.0000
# iprec_at_recall_0.70     43      0.0000
# iprec_at_recall_0.80     43      0.0000
# iprec_at_recall_0.90     43      0.0000
# iprec_at_recall_1.00     43      0.0000
# P_5                      43      0.0000
# P_10                     43      0.0000
# P_15                     43      0.0000
# P_20                     43      0.0000
# P_30                     43      0.0000
# P_100                    43      0.0000
# P_200                    43      0.0000
# P_500                    43      0.0000
# P_1000                   43      0.0000
# relstring                43      0.0000
# recall_5                 43      0.0000
# recall_10                43      0.0000
# recall_15                43      0.0000
# recall_20                43      0.0000
# recall_30                43      0.0000
# recall_100               43      0.0000
# recall_200               43      0.0000
# recall_500               43      0.0000
# recall_1000              43      0.0000
# infAP                    43      0.0000
# gm_bpref                 43      -11.5129
# Rprec_mult_0.20          43      0.0000
# Rprec_mult_0.40          43      0.0000
# Rprec_mult_0.60          43      0.0000
# Rprec_mult_0.80          43      0.0000
# Rprec_mult_1.00          43      0.0000
# Rprec_mult_1.20          43      0.0000
# Rprec_mult_1.40          43      0.0000
# Rprec_mult_1.60          43      0.0000
# Rprec_mult_1.80          43      0.0000
# Rprec_mult_2.00          43      0.0000
# utility                  43      -1.0000
# 11pt_avg                 43      0.0000
# binG                     43      0.0000
# G                        43      0.0000
# ndcg                     43      0.0000
# ndcg_rel                 43      0.0000
# Rndcg                    43      0.0000
# ndcg_cut_5               43      0.0000
# ndcg_cut_10              43      0.0000
# ndcg_cut_15              43      0.0000
# ndcg_cut_20              43      0.0000
# ndcg_cut_30              43      0.0000
# ndcg_cut_100             43      0.0000
# ndcg_cut_200             43      0.0000
# ndcg_cut_500             43      0.0000
# ndcg_cut_1000            43      0.0000
# map_cut_5                43      0.0000
# map_cut_10               43      0.0000
# map_cut_15               43      0.0000
# map_cut_20               43      0.0000
# map_cut_30               43      0.0000
# map_cut_100              43      0.0000
# map_cut_200              43      0.0000
# map_cut_500              43      0.0000
# map_cut_1000             43      0.0000
# relative_P_5             43      0.0000
# relative_P_10            43      0.0000
# relative_P_15            43      0.0000
# relative_P_20            43      0.0000
# relative_P_30            43      0.0000
# relative_P_100           43      0.0000
# relative_P_200           43      0.0000
# relative_P_500           43      0.0000
# relative_P_1000          43      0.0000
# success_1                43      0.0000
# success_5                43      0.0000
# success_10               43      0.0000
# set_P                    43      0.0000
# set_relative_P           43      0.0000
# set_recall               43      0.0000
# set_map                  43      0.0000
# set_F                    43      0.0000
# num_nonrel_judged_ret    43      0.0000
# num_q                    47      1.0000
# num_ret                  47      1.0000
# num_rel                  47      1.0000
# num_rel_ret              47      0.0000
# map                      47      0.0000
# gm_map                   47      -11.5129
# Rprec                    47      0.0000
# bpref                    47      0.0000
# recip_rank               47      0.0000
# iprec_at_recall_0.00     47      0.0000
# iprec_at_recall_0.10     47      0.0000
# iprec_at_recall_0.20     47      0.0000
# iprec_at_recall_0.30     47      0.0000
# iprec_at_recall_0.40     47      0.0000
# iprec_at_recall_0.50     47      0.0000
# iprec_at_recall_0.60     47      0.0000
# iprec_at_recall_0.70     47      0.0000
# iprec_at_recall_0.80     47      0.0000
# iprec_at_recall_0.90     47      0.0000
# iprec_at_recall_1.00     47      0.0000
# P_5                      47      0.0000
# P_10                     47      0.0000
# P_15                     47      0.0000
# P_20                     47      0.0000
# P_30                     47      0.0000
# P_100                    47      0.0000
# P_200                    47      0.0000
# P_500                    47      0.0000
# P_1000                   47      0.0000
# relstring                47      0.0000
# recall_5                 47      0.0000
# recall_10                47      0.0000
# recall_15                47      0.0000
# recall_20                47      0.0000
# recall_30                47      0.0000
# recall_100               47      0.0000
# recall_200               47      0.0000
# recall_500               47      0.0000
# recall_1000              47      0.0000
# infAP                    47      0.0000
# gm_bpref                 47      -11.5129
# Rprec_mult_0.20          47      0.0000
# Rprec_mult_0.40          47      0.0000
# Rprec_mult_0.60          47      0.0000
# Rprec_mult_0.80          47      0.0000
# Rprec_mult_1.00          47      0.0000
# Rprec_mult_1.20          47      0.0000
# Rprec_mult_1.40          47      0.0000
# Rprec_mult_1.60          47      0.0000
# Rprec_mult_1.80          47      0.0000
# Rprec_mult_2.00          47      0.0000
# utility                  47      -1.0000
# 11pt_avg                 47      0.0000
# binG                     47      0.0000
# G                        47      0.0000
# ndcg                     47      0.0000
# ndcg_rel                 47      0.0000
# Rndcg                    47      0.0000
# ndcg_cut_5               47      0.0000
# ndcg_cut_10              47      0.0000
# ndcg_cut_15              47      0.0000
# ndcg_cut_20              47      0.0000
# ndcg_cut_30              47      0.0000
# ndcg_cut_100             47      0.0000
# ndcg_cut_200             47      0.0000
# ndcg_cut_500             47      0.0000
# ndcg_cut_1000            47      0.0000
# map_cut_5                47      0.0000
# map_cut_10               47      0.0000
# map_cut_15               47      0.0000
# map_cut_20               47      0.0000
# map_cut_30               47      0.0000
# map_cut_100              47      0.0000
# map_cut_200              47      0.0000
# map_cut_500              47      0.0000
# map_cut_1000             47      0.0000
# relative_P_5             47      0.0000
# relative_P_10            47      0.0000
# relative_P_15            47      0.0000
# relative_P_20            47      0.0000
# relative_P_30            47      0.0000
# relative_P_100           47      0.0000
# relative_P_200           47      0.0000
# relative_P_500           47      0.0000
# relative_P_1000          47      0.0000
# success_1                47      0.0000
# success_5                47      0.0000
# success_10               47      0.0000
# set_P                    47      0.0000
# set_relative_P           47      0.0000
# set_recall               47      0.0000
# set_map                  47      0.0000
# set_F                    47      0.0000
# num_nonrel_judged_ret    47      1.0000
# num_q                    all     14.0000
# num_ret                  all     156.0000
# num_rel                  all     31.0000
# num_rel_ret              all     5.0000
# map                      all     0.2365
# gm_map                   all     0.0005
# Rprec                    all     0.2381
# bpref                    all     0.2222
# recip_rank               all     0.2524
# iprec_at_recall_0.00     all     0.2524
# iprec_at_recall_0.10     all     0.2524
# iprec_at_recall_0.20     all     0.2524
# iprec_at_recall_0.30     all     0.2524
# iprec_at_recall_0.40     all     0.2286
# iprec_at_recall_0.50     all     0.2286
# iprec_at_recall_0.60     all     0.2286
# iprec_at_recall_0.70     all     0.2286
# iprec_at_recall_0.80     all     0.2286
# iprec_at_recall_0.90     all     0.2286
# iprec_at_recall_1.00     all     0.2286
# P_5                      all     0.0714
# P_10                     all     0.0357
# P_15                     all     0.0238
# P_20                     all     0.0179
# P_30                     all     0.0119
# P_100                    all     0.0036
# P_200                    all     0.0018
# P_500                    all     0.0007
# P_1000                   all     0.0004
# relstring                all     0.0000
# recall_5                 all     0.3095
# recall_10                all     0.3095
# recall_15                all     0.3095
# recall_20                all     0.3095
# recall_30                all     0.3095
# recall_100               all     0.3095
# recall_200               all     0.3095
# recall_500               all     0.3095
# recall_1000              all     0.3095
# infAP                    all     0.2365
# gm_bpref                 all     0.0002
# Rprec_mult_0.20          all     0.2143
# Rprec_mult_0.40          all     0.2143
# Rprec_mult_0.60          all     0.2143
# Rprec_mult_0.80          all     0.2381
# Rprec_mult_1.00          all     0.2381
# Rprec_mult_1.20          all     0.1250
# Rprec_mult_1.40          all     0.1214
# Rprec_mult_1.60          all     0.1214
# Rprec_mult_1.80          all     0.1190
# Rprec_mult_2.00          all     0.1190
# utility                  all     -10.4286
# 11pt_avg                 all     0.2372
# binG                     all     0.2538
# G                        all     0.2538
# ndcg                     all     0.2587
# ndcg_rel                 all     0.2587
# Rndcg                    all     0.2449
# ndcg_cut_5               all     0.2587
# ndcg_cut_10              all     0.2587
# ndcg_cut_15              all     0.2587
# ndcg_cut_20              all     0.2587
# ndcg_cut_30              all     0.2587
# ndcg_cut_100             all     0.2587
# ndcg_cut_200             all     0.2587
# ndcg_cut_500             all     0.2587
# ndcg_cut_1000            all     0.2587
# map_cut_5                all     0.2365
# map_cut_10               all     0.2365
# map_cut_15               all     0.2365
# map_cut_20               all     0.2365
# map_cut_30               all     0.2365
# map_cut_100              all     0.2365
# map_cut_200              all     0.2365
# map_cut_500              all     0.2365
# map_cut_1000             all     0.2365
# relative_P_5             all     0.3095
# relative_P_10            all     0.3095
# relative_P_15            all     0.3095
# relative_P_20            all     0.3095
# relative_P_30            all     0.3095
# relative_P_100           all     0.3095
# relative_P_200           all     0.3095
# relative_P_500           all     0.3095
# relative_P_1000          all     0.3095
# success_1                all     0.2143
# success_5                all     0.3571
# success_10               all     0.3571
# set_P                    all     0.0239
# set_relative_P           all     0.3095
# set_recall               all     0.3095
# set_map                  all     0.0220
# set_F                    all     0.0436
# num_nonrel_judged_ret    all     105.0000

# %%
q2.print_rel_name('1')
# Out:
# ---------------------------Topic_id and Topic_phrase----------------------------------
# 1 mining gold silver coal
# ---------------------------Return documents----------------------------------
# 1 Q0 G00-90-0342721 0 26.645398 test
# ---------------------------Relevant documents----------------------------------
# 1 0 G00-00-1006224 1
# 1 0 G00-02-0901987 1
# 1 0 G00-03-1898526 1
# 1 0 G00-10-3730888 1
# 1 0 G00-10-3849661 1

# %% [markdown]
# ### Q2 (b): Provide answer to Q2 (b) here [markdown cell]
#
# 0.2365

# %% [markdown]
# ### Q2 (c): Provide answer to Q2(c) here [markdown cell]
#
# Very well: 18, 24, 33
#
# Very poorly: 1, 2, 6, 9

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Q3 (a): Provide answer to Q3 (a) here [markdown cell]
#
# false negative: G00-00-0901987 in query 1 about mining gold silver coal. It should be positive but being classified as negative.
#
# false positive: G00-90-0342721 in query 1 about mining gold silver coal. It should be nagative but being classified as postive.
#
# The reason that document G00-90-0342721 being the wrong result returned in the vanilla whoosh class is that it contains all relevant words of the query: mining, gold, silver, and coal even though the information it contains is only about parks and there mining histories.
#
# Whereas, document G00-00-0901987 being the unretreived result even though it is more related is that we did not set the search group on the query words. The defualt is ANDGroup and only a document contains all the query words exactly will be returned. Hence, we are missing this one even though its content is more related to mining jobs.
#
# Something to improve on is that the IR class could do a little bit more parsing on both the query and documents because mine word itself or gold mine the phrase could also be related to the query but they will never be considered in vanilla whoosh thus missing the boolean retrieval stage. At the same time, ORGroup should be also be applied to retrieve more results during Boolean Retrieval Stage.
#
# What would also be helpful is to consider the context of both the query and the document to make the search more accurate in terms of content rather than simply matching words.

# %% [markdown]
# ### Q3 (b): Write your code below

# %% [markdown]
# **1. The auto-grader will extract and use the following variables, DON'T change the their names:**
#
#       self.topic_file
#       self.qrels_file
#       self.document_dir
#       self.file_list
#       self.index_sys
#       self.query_parser
#       self.searcher
#
#
#
# **2. DON'T change the names of the already defined funtions**
# **3. DON'T change the py_trec_eval function**
# **4. DON'T change the class names including CustomFilter, IRSystem, IRQ2, IRQ3, IRQ4**
# **5. DON'T change the CustomFilter class and DON'T create any new custom filter class that is used to define Whoosh schema**

# %%
class IRQ3(IRSystem):
    def create_index(self):
        """
        INPUT:
            None
        OUTPUT:
            None

        NOTE: Please update self.index_sys which should have type whoosh.index.FileIndex
        """
        # DON't change the name of 'index_sys'
        myAnalyzer = RegexTokenizer() | LowercaseFilter() | IntraWordFilter() | StopFilter() | CustomFilter(LancasterStemmer().stem)
        schema = Schema(file_path = ID(stored=True), file_content = TEXT(analyzer = myAnalyzer))
        indexDir = tempfile.mkdtemp()
        self.index_sys = index.create_in(indexDir, schema)

    def add_files(self):
        """
        INPUT:
            None
        OUTPUT:
            None

        NOTE: Add buffer to self.index_sys
        """
        writer = writing.BufferedWriter(self.index_sys, period=None, limit=1000)
        file_contents=[]
        try:
            for docNum, filePath in enumerate(self.file_list):
                with open(filePath, "r", encoding="utf-8") as f:
                    content = f.read()
                    writer.add_document(file_path = filePath, file_content = content)
                    file_contents.append(content)
        finally:
            # close the index
            writer.close()

    def create_parser_searcher(self):
        """
        INPUT:
            None
        OUTPUT:
            None

        NOTE: Please update self.query_parser and self.self.searcherwhich should have type whoosh.qparser.default.QueryParser and whoosh.searching.Searcher respectively
        """
         # DON't change the names of 'query_parser' and 'searcher'
        self.query_parser = QueryParser("file_content", schema=self.index_sys.schema, group=qparser.OrGroup)
        self.searcher = self.index_sys.searcher()

    def perform_search(self, topic_phrase):
        """
        INPUT:
            topic_phrase: string
        OUTPUT:
            topicResults: whoosh.searching.Results

        NOTE: Utilize self.query_parser and self.searcher to calculate the result for topic_phrase
        """
        query = self.query_parser.parse(topic_phrase)
        topicResults = self.searcher.search(query, limit=None)
        return topicResults

# %%
q3 = IRQ3("government")

# %%
q3.add_files()

# %%
q3.py_trec_eval()
# Out:
# num_q                    1       1.0000
# num_ret                  1       481.0000
# num_rel                  1       5.0000
# num_rel_ret              1       5.0000
# map                      1       0.0618
# gm_map                   1       -2.7839
# Rprec                    1       0.0000
# bpref                    1       0.0000
# recip_rank               1       0.0500
# iprec_at_recall_0.00     1       0.0968
# iprec_at_recall_0.10     1       0.0968
# iprec_at_recall_0.20     1       0.0968
# iprec_at_recall_0.30     1       0.0968
# iprec_at_recall_0.40     1       0.0968
# iprec_at_recall_0.50     1       0.0968
# iprec_at_recall_0.60     1       0.0968
# iprec_at_recall_0.70     1       0.0412
# iprec_at_recall_0.80     1       0.0412
# iprec_at_recall_0.90     1       0.0410
# iprec_at_recall_1.00     1       0.0410
# P_5                      1       0.0000
# P_10                     1       0.0000
# P_15                     1       0.0000
# P_20                     1       0.0500
# P_30                     1       0.0667
# P_100                    1       0.0400
# P_200                    1       0.0250
# P_500                    1       0.0100
# P_1000                   1       0.0050
# relstring                1       0.0000
# recall_5                 1       0.0000
# recall_10                1       0.0000
# recall_15                1       0.0000
# recall_20                1       0.2000
# recall_30                1       0.4000
# recall_100               1       0.8000
# recall_200               1       1.0000
# recall_500               1       1.0000
# recall_1000              1       1.0000
# infAP                    1       0.0618
# gm_bpref                 1       -11.5129
# Rprec_mult_0.20          1       0.0000
# Rprec_mult_0.40          1       0.0000
# Rprec_mult_0.60          1       0.0000
# Rprec_mult_0.80          1       0.0000
# Rprec_mult_1.00          1       0.0000
# Rprec_mult_1.20          1       0.0000
# Rprec_mult_1.40          1       0.0000
# Rprec_mult_1.60          1       0.0000
# Rprec_mult_1.80          1       0.0000
# Rprec_mult_2.00          1       0.0000
# utility                  1       -471.0000
# 11pt_avg                 1       0.0765
# binG                     1       0.1888
# G                        1       0.1888
# ndcg                     1       0.3173
# ndcg_rel                 1       0.2059
# Rndcg                    1       0.1587
# ndcg_cut_5               1       0.0000
# ndcg_cut_10              1       0.0000
# ndcg_cut_15              1       0.0000
# ndcg_cut_20              1       0.0772
# ndcg_cut_30              1       0.1494
# ndcg_cut_100             1       0.2685
# ndcg_cut_200             1       0.3173
# ndcg_cut_500             1       0.3173
# ndcg_cut_1000            1       0.3173
# map_cut_5                1       0.0000
# map_cut_10               1       0.0000
# map_cut_15               1       0.0000
# map_cut_20               1       0.0100
# map_cut_30               1       0.0260
# map_cut_100              1       0.0536
# map_cut_200              1       0.0618
# map_cut_500              1       0.0618
# map_cut_1000             1       0.0618
# relative_P_5             1       0.0000
# relative_P_10            1       0.0000
# relative_P_15            1       0.0000
# relative_P_20            1       0.2000
# relative_P_30            1       0.4000
# relative_P_100           1       0.8000
# relative_P_200           1       1.0000
# relative_P_500           1       1.0000
# relative_P_1000          1       1.0000
# success_1                1       0.0000
# success_5                1       0.0000
# success_10               1       0.0000
# set_P                    1       0.0104
# set_relative_P           1       1.0000
# set_recall               1       1.0000
# set_map                  1       0.0104
# set_F                    1       0.0206
# num_nonrel_judged_ret    1       68.0000
# num_q                    2       1.0000
# num_ret                  2       59.0000
# num_rel                  2       2.0000
# num_rel_ret              2       2.0000
# map                      2       0.5357
# gm_map                   2       -0.6242
# Rprec                    2       0.5000
# bpref                    2       0.5000
# recip_rank               2       1.0000
# iprec_at_recall_0.00     2       1.0000
# iprec_at_recall_0.10     2       1.0000
# iprec_at_recall_0.20     2       1.0000
# iprec_at_recall_0.30     2       1.0000
# iprec_at_recall_0.40     2       1.0000
# iprec_at_recall_0.50     2       1.0000
# iprec_at_recall_0.60     2       0.0714
# iprec_at_recall_0.70     2       0.0714
# iprec_at_recall_0.80     2       0.0714
# iprec_at_recall_0.90     2       0.0714
# iprec_at_recall_1.00     2       0.0714
# P_5                      2       0.2000
# P_10                     2       0.1000
# P_15                     2       0.0667
# P_20                     2       0.0500
# P_30                     2       0.0667
# P_100                    2       0.0200
# P_200                    2       0.0100
# P_500                    2       0.0040
# P_1000                   2       0.0020
# relstring                2       0.0000
# recall_5                 2       0.5000
# recall_10                2       0.5000
# recall_15                2       0.5000
# recall_20                2       0.5000
# recall_30                2       1.0000
# recall_100               2       1.0000
# recall_200               2       1.0000
# recall_500               2       1.0000
# recall_1000              2       1.0000
# infAP                    2       0.5357
# gm_bpref                 2       -0.6931
# Rprec_mult_0.20          2       1.0000
# Rprec_mult_0.40          2       1.0000
# Rprec_mult_0.60          2       0.5000
# Rprec_mult_0.80          2       0.5000
# Rprec_mult_1.00          2       0.5000
# Rprec_mult_1.20          2       0.3333
# Rprec_mult_1.40          2       0.3333
# Rprec_mult_1.60          2       0.2500
# Rprec_mult_1.80          2       0.2500
# Rprec_mult_2.00          2       0.2500
# utility                  2       -55.0000
# 11pt_avg                 2       0.5779
# binG                     2       0.6040
# G                        2       0.6040
# ndcg                     2       0.7394
# ndcg_rel                 2       0.8697
# Rndcg                    2       0.6763
# ndcg_cut_5               2       0.6131
# ndcg_cut_10              2       0.6131
# ndcg_cut_15              2       0.6131
# ndcg_cut_20              2       0.6131
# ndcg_cut_30              2       0.7394
# ndcg_cut_100             2       0.7394
# ndcg_cut_200             2       0.7394
# ndcg_cut_500             2       0.7394
# ndcg_cut_1000            2       0.7394
# map_cut_5                2       0.5000
# map_cut_10               2       0.5000
# map_cut_15               2       0.5000
# map_cut_20               2       0.5000
# map_cut_30               2       0.5357
# map_cut_100              2       0.5357
# map_cut_200              2       0.5357
# map_cut_500              2       0.5357
# map_cut_1000             2       0.5357
# relative_P_5             2       0.5000
# relative_P_10            2       0.5000
# relative_P_15            2       0.5000
# relative_P_20            2       0.5000
# relative_P_30            2       1.0000
# relative_P_100           2       1.0000
# relative_P_200           2       1.0000
# relative_P_500           2       1.0000
# relative_P_1000          2       1.0000
# success_1                2       1.0000
# success_5                2       1.0000
# success_10               2       1.0000
# set_P                    2       0.0339
# set_relative_P           2       1.0000
# set_recall               2       1.0000
# set_map                  2       0.0339
# set_F                    2       0.0656
# num_nonrel_judged_ret    2       28.0000
# num_q                    6       1.0000
# num_ret                  6       450.0000
# num_rel                  6       1.0000
# num_rel_ret              6       1.0000
# map                      6       0.0263
# gm_map                   6       -3.6376
# Rprec                    6       0.0000
# bpref                    6       0.0000
# recip_rank               6       0.0263
# iprec_at_recall_0.00     6       0.0263
# iprec_at_recall_0.10     6       0.0263
# iprec_at_recall_0.20     6       0.0263
# iprec_at_recall_0.30     6       0.0263
# iprec_at_recall_0.40     6       0.0263
# iprec_at_recall_0.50     6       0.0263
# iprec_at_recall_0.60     6       0.0263
# iprec_at_recall_0.70     6       0.0263
# iprec_at_recall_0.80     6       0.0263
# iprec_at_recall_0.90     6       0.0263
# iprec_at_recall_1.00     6       0.0263
# P_5                      6       0.0000
# P_10                     6       0.0000
# P_15                     6       0.0000
# P_20                     6       0.0000
# P_30                     6       0.0000
# P_100                    6       0.0100
# P_200                    6       0.0050
# P_500                    6       0.0020
# P_1000                   6       0.0010
# relstring                6       0.0000
# recall_5                 6       0.0000
# recall_10                6       0.0000
# recall_15                6       0.0000
# recall_20                6       0.0000
# recall_30                6       0.0000
# recall_100               6       1.0000
# recall_200               6       1.0000
# recall_500               6       1.0000
# recall_1000              6       1.0000
# infAP                    6       0.0263
# gm_bpref                 6       -11.5129
# Rprec_mult_0.20          6       0.0000
# Rprec_mult_0.40          6       0.0000
# Rprec_mult_0.60          6       0.0000
# Rprec_mult_0.80          6       0.0000
# Rprec_mult_1.00          6       0.0000
# Rprec_mult_1.20          6       0.0000
# Rprec_mult_1.40          6       0.0000
# Rprec_mult_1.60          6       0.0000
# Rprec_mult_1.80          6       0.0000
# Rprec_mult_2.00          6       0.0000
# utility                  6       -448.0000
# 11pt_avg                 6       0.0263
# binG                     6       0.1892
# G                        6       0.1892
# ndcg                     6       0.1892
# ndcg_rel                 6       0.1892
# Rndcg                    6       0.0946
# ndcg_cut_5               6       0.0000
# ndcg_cut_10              6       0.0000
# ndcg_cut_15              6       0.0000
# ndcg_cut_20              6       0.0000
# ndcg_cut_30              6       0.0000
# ndcg_cut_100             6       0.1892
# ndcg_cut_200             6       0.1892
# ndcg_cut_500             6       0.1892
# ndcg_cut_1000            6       0.1892
# map_cut_5                6       0.0000
# map_cut_10               6       0.0000
# map_cut_15               6       0.0000
# map_cut_20               6       0.0000
# map_cut_30               6       0.0000
# map_cut_100              6       0.0263
# map_cut_200              6       0.0263
# map_cut_500              6       0.0263
# map_cut_1000             6       0.0263
# relative_P_5             6       0.0000
# relative_P_10            6       0.0000
# relative_P_15            6       0.0000
# relative_P_20            6       0.0000
# relative_P_30            6       0.0000
# relative_P_100           6       1.0000
# relative_P_200           6       1.0000
# relative_P_500           6       1.0000
# relative_P_1000          6       1.0000
# success_1                6       0.0000
# success_5                6       0.0000
# success_10               6       0.0000
# set_P                    6       0.0022
# set_relative_P           6       1.0000
# set_recall               6       1.0000
# set_map                  6       0.0022
# set_F                    6       0.0044
# num_nonrel_judged_ret    6       93.0000
# num_q                    9       1.0000
# num_ret                  9       1856.0000
# num_rel                  9       1.0000
# num_rel_ret              9       1.0000
# map                      9       0.0588
# gm_map                   9       -2.8332
# Rprec                    9       0.0000
# bpref                    9       0.0000
# recip_rank               9       0.0588
# iprec_at_recall_0.00     9       0.0588
# iprec_at_recall_0.10     9       0.0588
# iprec_at_recall_0.20     9       0.0588
# iprec_at_recall_0.30     9       0.0588
# iprec_at_recall_0.40     9       0.0588
# iprec_at_recall_0.50     9       0.0588
# iprec_at_recall_0.60     9       0.0588
# iprec_at_recall_0.70     9       0.0588
# iprec_at_recall_0.80     9       0.0588
# iprec_at_recall_0.90     9       0.0588
# iprec_at_recall_1.00     9       0.0588
# P_5                      9       0.0000
# P_10                     9       0.0000
# P_15                     9       0.0000
# P_20                     9       0.0500
# P_30                     9       0.0333
# P_100                    9       0.0100
# P_200                    9       0.0050
# P_500                    9       0.0020
# P_1000                   9       0.0010
# relstring                9       0.0000
# recall_5                 9       0.0000
# recall_10                9       0.0000
# recall_15                9       0.0000
# recall_20                9       1.0000
# recall_30                9       1.0000
# recall_100               9       1.0000
# recall_200               9       1.0000
# recall_500               9       1.0000
# recall_1000              9       1.0000
# infAP                    9       0.0588
# gm_bpref                 9       -11.5129
# Rprec_mult_0.20          9       0.0000
# Rprec_mult_0.40          9       0.0000
# Rprec_mult_0.60          9       0.0000
# Rprec_mult_0.80          9       0.0000
# Rprec_mult_1.00          9       0.0000
# Rprec_mult_1.20          9       0.0000
# Rprec_mult_1.40          9       0.0000
# Rprec_mult_1.60          9       0.0000
# Rprec_mult_1.80          9       0.0000
# Rprec_mult_2.00          9       0.0000
# utility                  9       -1854.0000
# 11pt_avg                 9       0.0588
# binG                     9       0.2398
# G                        9       0.2398
# ndcg                     9       0.2398
# ndcg_rel                 9       0.2398
# Rndcg                    9       0.1199
# ndcg_cut_5               9       0.0000
# ndcg_cut_10              9       0.0000
# ndcg_cut_15              9       0.0000
# ndcg_cut_20              9       0.2398
# ndcg_cut_30              9       0.2398
# ndcg_cut_100             9       0.2398
# ndcg_cut_200             9       0.2398
# ndcg_cut_500             9       0.2398
# ndcg_cut_1000            9       0.2398
# map_cut_5                9       0.0000
# map_cut_10               9       0.0000
# map_cut_15               9       0.0000
# map_cut_20               9       0.0588
# map_cut_30               9       0.0588
# map_cut_100              9       0.0588
# map_cut_200              9       0.0588
# map_cut_500              9       0.0588
# map_cut_1000             9       0.0588
# relative_P_5             9       0.0000
# relative_P_10            9       0.0000
# relative_P_15            9       0.0000
# relative_P_20            9       1.0000
# relative_P_30            9       1.0000
# relative_P_100           9       1.0000
# relative_P_200           9       1.0000
# relative_P_500           9       1.0000
# relative_P_1000          9       1.0000
# success_1                9       0.0000
# success_5                9       0.0000
# success_10               9       0.0000
# set_P                    9       0.0005
# set_relative_P           9       1.0000
# set_recall               9       1.0000
# set_map                  9       0.0005
# set_F                    9       0.0011
# num_nonrel_judged_ret    9       170.0000
# num_q                    18      1.0000
# num_ret                  18      32.0000
# num_rel                  18      1.0000
# num_rel_ret              18      1.0000
# map                      18      1.0000
# gm_map                   18      0.0000
# Rprec                    18      1.0000
# bpref                    18      1.0000
# recip_rank               18      1.0000
# iprec_at_recall_0.00     18      1.0000
# iprec_at_recall_0.10     18      1.0000
# iprec_at_recall_0.20     18      1.0000
# iprec_at_recall_0.30     18      1.0000
# iprec_at_recall_0.40     18      1.0000
# iprec_at_recall_0.50     18      1.0000
# iprec_at_recall_0.60     18      1.0000
# iprec_at_recall_0.70     18      1.0000
# iprec_at_recall_0.80     18      1.0000
# iprec_at_recall_0.90     18      1.0000
# iprec_at_recall_1.00     18      1.0000
# P_5                      18      0.2000
# P_10                     18      0.1000
# P_15                     18      0.0667
# P_20                     18      0.0500
# P_30                     18      0.0333
# P_100                    18      0.0100
# P_200                    18      0.0050
# P_500                    18      0.0020
# P_1000                   18      0.0010
# relstring                18      0.0000
# recall_5                 18      1.0000
# recall_10                18      1.0000
# recall_15                18      1.0000
# recall_20                18      1.0000
# recall_30                18      1.0000
# recall_100               18      1.0000
# recall_200               18      1.0000
# recall_500               18      1.0000
# recall_1000              18      1.0000
# infAP                    18      1.0000
# gm_bpref                 18      0.0000
# Rprec_mult_0.20          18      1.0000
# Rprec_mult_0.40          18      1.0000
# Rprec_mult_0.60          18      1.0000
# Rprec_mult_0.80          18      1.0000
# Rprec_mult_1.00          18      1.0000
# Rprec_mult_1.20          18      0.5000
# Rprec_mult_1.40          18      0.5000
# Rprec_mult_1.60          18      0.5000
# Rprec_mult_1.80          18      0.5000
# Rprec_mult_2.00          18      0.5000
# utility                  18      -30.0000
# 11pt_avg                 18      1.0000
# binG                     18      1.0000
# G                        18      1.0000
# ndcg                     18      1.0000
# ndcg_rel                 18      1.0000
# Rndcg                    18      1.0000
# ndcg_cut_5               18      1.0000
# ndcg_cut_10              18      1.0000
# ndcg_cut_15              18      1.0000
# ndcg_cut_20              18      1.0000
# ndcg_cut_30              18      1.0000
# ndcg_cut_100             18      1.0000
# ndcg_cut_200             18      1.0000
# ndcg_cut_500             18      1.0000
# ndcg_cut_1000            18      1.0000
# map_cut_5                18      1.0000
# map_cut_10               18      1.0000
# map_cut_15               18      1.0000
# map_cut_20               18      1.0000
# map_cut_30               18      1.0000
# map_cut_100              18      1.0000
# map_cut_200              18      1.0000
# map_cut_500              18      1.0000
# map_cut_1000             18      1.0000
# relative_P_5             18      1.0000
# relative_P_10            18      1.0000
# relative_P_15            18      1.0000
# relative_P_20            18      1.0000
# relative_P_30            18      1.0000
# relative_P_100           18      1.0000
# relative_P_200           18      1.0000
# relative_P_500           18      1.0000
# relative_P_1000          18      1.0000
# success_1                18      1.0000
# success_5                18      1.0000
# success_10               18      1.0000
# set_P                    18      0.0312
# set_relative_P           18      1.0000
# set_recall               18      1.0000
# set_map                  18      0.0312
# set_F                    18      0.0606
# num_nonrel_judged_ret    18      30.0000
# num_q                    22      1.0000
# num_ret                  22      468.0000
# num_rel                  22      1.0000
# num_rel_ret              22      1.0000
# map                      22      0.0357
# gm_map                   22      -3.3322
# Rprec                    22      0.0000
# bpref                    22      0.0000
# recip_rank               22      0.0357
# iprec_at_recall_0.00     22      0.0357
# iprec_at_recall_0.10     22      0.0357
# iprec_at_recall_0.20     22      0.0357
# iprec_at_recall_0.30     22      0.0357
# iprec_at_recall_0.40     22      0.0357
# iprec_at_recall_0.50     22      0.0357
# iprec_at_recall_0.60     22      0.0357
# iprec_at_recall_0.70     22      0.0357
# iprec_at_recall_0.80     22      0.0357
# iprec_at_recall_0.90     22      0.0357
# iprec_at_recall_1.00     22      0.0357
# P_5                      22      0.0000
# P_10                     22      0.0000
# P_15                     22      0.0000
# P_20                     22      0.0000
# P_30                     22      0.0333
# P_100                    22      0.0100
# P_200                    22      0.0050
# P_500                    22      0.0020
# P_1000                   22      0.0010
# relstring                22      0.0000
# recall_5                 22      0.0000
# recall_10                22      0.0000
# recall_15                22      0.0000
# recall_20                22      0.0000
# recall_30                22      1.0000
# recall_100               22      1.0000
# recall_200               22      1.0000
# recall_500               22      1.0000
# recall_1000              22      1.0000
# infAP                    22      0.0357
# gm_bpref                 22      -11.5129
# Rprec_mult_0.20          22      0.0000
# Rprec_mult_0.40          22      0.0000
# Rprec_mult_0.60          22      0.0000
# Rprec_mult_0.80          22      0.0000
# Rprec_mult_1.00          22      0.0000
# Rprec_mult_1.20          22      0.0000
# Rprec_mult_1.40          22      0.0000
# Rprec_mult_1.60          22      0.0000
# Rprec_mult_1.80          22      0.0000
# Rprec_mult_2.00          22      0.0000
# utility                  22      -466.0000
# 11pt_avg                 22      0.0357
# binG                     22      0.2058
# G                        22      0.2058
# ndcg                     22      0.2058
# ndcg_rel                 22      0.2058
# Rndcg                    22      0.1029
# ndcg_cut_5               22      0.0000
# ndcg_cut_10              22      0.0000
# ndcg_cut_15              22      0.0000
# ndcg_cut_20              22      0.0000
# ndcg_cut_30              22      0.2058
# ndcg_cut_100             22      0.2058
# ndcg_cut_200             22      0.2058
# ndcg_cut_500             22      0.2058
# ndcg_cut_1000            22      0.2058
# map_cut_5                22      0.0000
# map_cut_10               22      0.0000
# map_cut_15               22      0.0000
# map_cut_20               22      0.0000
# map_cut_30               22      0.0357
# map_cut_100              22      0.0357
# map_cut_200              22      0.0357
# map_cut_500              22      0.0357
# map_cut_1000             22      0.0357
# relative_P_5             22      0.0000
# relative_P_10            22      0.0000
# relative_P_15            22      0.0000
# relative_P_20            22      0.0000
# relative_P_30            22      1.0000
# relative_P_100           22      1.0000
# relative_P_200           22      1.0000
# relative_P_500           22      1.0000
# relative_P_1000          22      1.0000
# success_1                22      0.0000
# success_5                22      0.0000
# success_10               22      0.0000
# set_P                    22      0.0021
# set_relative_P           22      1.0000
# set_recall               22      1.0000
# set_map                  22      0.0021
# set_F                    22      0.0043
# num_nonrel_judged_ret    22      128.0000
# num_q                    24      1.0000
# num_ret                  24      771.0000
# num_rel                  24      1.0000
# num_rel_ret              24      1.0000
# map                      24      1.0000
# gm_map                   24      0.0000
# Rprec                    24      1.0000
# bpref                    24      1.0000
# recip_rank               24      1.0000
# iprec_at_recall_0.00     24      1.0000
# iprec_at_recall_0.10     24      1.0000
# iprec_at_recall_0.20     24      1.0000
# iprec_at_recall_0.30     24      1.0000
# iprec_at_recall_0.40     24      1.0000
# iprec_at_recall_0.50     24      1.0000
# iprec_at_recall_0.60     24      1.0000
# iprec_at_recall_0.70     24      1.0000
# iprec_at_recall_0.80     24      1.0000
# iprec_at_recall_0.90     24      1.0000
# iprec_at_recall_1.00     24      1.0000
# P_5                      24      0.2000
# P_10                     24      0.1000
# P_15                     24      0.0667
# P_20                     24      0.0500
# P_30                     24      0.0333
# P_100                    24      0.0100
# P_200                    24      0.0050
# P_500                    24      0.0020
# P_1000                   24      0.0010
# relstring                24      0.0000
# recall_5                 24      1.0000
# recall_10                24      1.0000
# recall_15                24      1.0000
# recall_20                24      1.0000
# recall_30                24      1.0000
# recall_100               24      1.0000
# recall_200               24      1.0000
# recall_500               24      1.0000
# recall_1000              24      1.0000
# infAP                    24      1.0000
# gm_bpref                 24      0.0000
# Rprec_mult_0.20          24      1.0000
# Rprec_mult_0.40          24      1.0000
# Rprec_mult_0.60          24      1.0000
# Rprec_mult_0.80          24      1.0000
# Rprec_mult_1.00          24      1.0000
# Rprec_mult_1.20          24      0.5000
# Rprec_mult_1.40          24      0.5000
# Rprec_mult_1.60          24      0.5000
# Rprec_mult_1.80          24      0.5000
# Rprec_mult_2.00          24      0.5000
# utility                  24      -769.0000
# 11pt_avg                 24      1.0000
# binG                     24      1.0000
# G                        24      1.0000
# ndcg                     24      1.0000
# ndcg_rel                 24      1.0000
# Rndcg                    24      1.0000
# ndcg_cut_5               24      1.0000
# ndcg_cut_10              24      1.0000
# ndcg_cut_15              24      1.0000
# ndcg_cut_20              24      1.0000
# ndcg_cut_30              24      1.0000
# ndcg_cut_100             24      1.0000
# ndcg_cut_200             24      1.0000
# ndcg_cut_500             24      1.0000
# ndcg_cut_1000            24      1.0000
# map_cut_5                24      1.0000
# map_cut_10               24      1.0000
# map_cut_15               24      1.0000
# map_cut_20               24      1.0000
# map_cut_30               24      1.0000
# map_cut_100              24      1.0000
# map_cut_200              24      1.0000
# map_cut_500              24      1.0000
# map_cut_1000             24      1.0000
# relative_P_5             24      1.0000
# relative_P_10            24      1.0000
# relative_P_15            24      1.0000
# relative_P_20            24      1.0000
# relative_P_30            24      1.0000
# relative_P_100           24      1.0000
# relative_P_200           24      1.0000
# relative_P_500           24      1.0000
# relative_P_1000          24      1.0000
# success_1                24      1.0000
# success_5                24      1.0000
# success_10               24      1.0000
# set_P                    24      0.0013
# set_relative_P           24      1.0000
# set_recall               24      1.0000
# set_map                  24      0.0013
# set_F                    24      0.0026
# num_nonrel_judged_ret    24      122.0000
# num_q                    26      1.0000
# num_ret                  26      588.0000
# num_rel                  26      3.0000
# num_rel_ret              26      3.0000
# map                      26      0.1074
# gm_map                   26      -2.2315
# Rprec                    26      0.0000
# bpref                    26      0.0000
# recip_rank               26      0.1667
# iprec_at_recall_0.00     26      0.1667
# iprec_at_recall_0.10     26      0.1667
# iprec_at_recall_0.20     26      0.1667
# iprec_at_recall_0.30     26      0.1667
# iprec_at_recall_0.40     26      0.0909
# iprec_at_recall_0.50     26      0.0909
# iprec_at_recall_0.60     26      0.0909
# iprec_at_recall_0.70     26      0.0909
# iprec_at_recall_0.80     26      0.0909
# iprec_at_recall_0.90     26      0.0909
# iprec_at_recall_1.00     26      0.0909
# P_5                      26      0.0000
# P_10                     26      0.1000
# P_15                     26      0.0667
# P_20                     26      0.0500
# P_30                     26      0.0333
# P_100                    26      0.0300
# P_200                    26      0.0150
# P_500                    26      0.0060
# P_1000                   26      0.0030
# relstring                26      0.0000
# recall_5                 26      0.0000
# recall_10                26      0.3333
# recall_15                26      0.3333
# recall_20                26      0.3333
# recall_30                26      0.3333
# recall_100               26      1.0000
# recall_200               26      1.0000
# recall_500               26      1.0000
# recall_1000              26      1.0000
# infAP                    26      0.1074
# gm_bpref                 26      -11.5129
# Rprec_mult_0.20          26      0.0000
# Rprec_mult_0.40          26      0.0000
# Rprec_mult_0.60          26      0.0000
# Rprec_mult_0.80          26      0.0000
# Rprec_mult_1.00          26      0.0000
# Rprec_mult_1.20          26      0.0000
# Rprec_mult_1.40          26      0.0000
# Rprec_mult_1.60          26      0.0000
# Rprec_mult_1.80          26      0.1667
# Rprec_mult_2.00          26      0.1667
# utility                  26      
0000
# success_1                28      0.0000
# success_5                28      0.0000
# success_10               28      1.0000
# set_P                    28      0.0016
# set_relative_P           28      1.0000
# set_recall               28      1.0000
# set_map                  28      0.0016
# set_F                    28      0.0032
# num_nonrel_judged_ret    28      107.0000
# num_q                    32      1.0000
# num_ret                  32      243.0000
# num_rel                  32      8.0000
# num_rel_ret              32      5.0000
# map                      32      0.1513
# gm_map                   32      -1.8884
# Rprec                    32      0.1250
# bpref                    32      0.1250
# recip_rank               32      1.0000
# iprec_at_recall_0.00     32      1.0000
# iprec_at_recall_0.10     32      1.0000
# iprec_at_recall_0.20     32      0.0769
# iprec_at_recall_0.30     32      0.0500
# iprec_at_recall_0.40     32      0.0500
# iprec_at_recall_0.50     32      0.0500
# iprec_at_recall_0.60     32      0.0500
# iprec_at_recall_0.70     32      0.0000
# iprec_at_recall_0.80     32      0.0000
# iprec_at_recall_0.90     32      0.0000
# iprec_at_recall_1.00     32      0.0000
# P_5                      32      0.2000
# P_10                     32      0.1000
# P_15                     32      0.0667
# P_20                     32      0.0500
# P_30                     32      0.0667
# P_100                    32      0.0500
# P_200                    32      0.0250
# P_500                    32      0.0100
# P_1000                   32      0.0050
# relstring                32      0.0000
# recall_5                 32      0.1250
# recall_10                32      0.1250
# recall_15                32      0.1250
# recall_20                32      0.1250
# recall_30                32      0.2500
# recall_100               32      0.6250
# recall_200               32      0.6250
# recall_500               32      0.6250
# recall_1000              32      0.6250
# infAP                    32      0.1513
# gm_bpref                 32      -2.0794
# Rprec_mult_0.20          32      0.5000
# Rprec_mult_0.40          32      0.2500
# Rprec_mult_0.60          32      0.2000
# Rprec_mult_0.80          32      0.1429
# Rprec_mult_1.00          32      0.1250
# Rprec_mult_1.20          32      0.1000
# Rprec_mult_1.40          32      0.0833
# Rprec_mult_1.60          32      0.0769
# Rprec_mult_1.80          32      0.0667
# Rprec_mult_2.00          32      0.0625
# utility                  32      -233.0000
# 11pt_avg                 32      0.2070
# binG                     32      0.2099
# G                        32      0.2099
# ndcg                     32      0.4232
# ndcg_rel                 32      0.4662
# Rndcg                    32      0.3381
# ndcg_cut_5               32      0.3392
# ndcg_cut_10              32      0.2529
# ndcg_cut_15              32      0.2529
# ndcg_cut_20              32      0.2529
# ndcg_cut_30              32      0.3061
# ndcg_cut_100             32      0.4232
# ndcg_cut_200             32      0.4232
# ndcg_cut_500             32      0.4232
# ndcg_cut_1000            32      0.4232
# map_cut_5                32      0.1250
# map_cut_10               32      0.1250
# map_cut_15               32      0.1250
# map_cut_20               32      0.1250
# map_cut_30               32      0.1346
# map_cut_100              32      0.1513
# map_cut_200              32      0.1513
# map_cut_500              32      0.1513
# map_cut_1000             32      0.1513
# relative_P_5             32      0.2000
# relative_P_10            32      0.1250
# relative_P_15            32      0.1250
# relative_P_20            32      0.1250
# relative_P_30            32      0.2500
# relative_P_100           32      0.6250
# relative_P_200           32      0.6250
# relative_P_500           32      0.6250
# relative_P_1000          32      0.6250
# success_1                32      1.0000
# success_5                32      1.0000
# success_10               32      1.0000
# set_P                    32      0.0206
# set_relative_P           32      0.6250
# set_recall               32      0.6250
# set_map                  32      0.0129
# set_F                    32      0.0398
# num_nonrel_judged_ret    32      28.0000
# num_q                    33      1.0000
# num_ret                  33      669.0000
# num_rel                  33      1.0000
# num_rel_ret              33      1.0000
# map                      33      1.0000
# gm_map                   33      0.0000
# Rprec                    33      1.0000
# bpref                    33      1.0000
# recip_rank               33      1.0000
# iprec_at_recall_0.00     33      1.0000
# iprec_at_recall_0.10     33      1.0000
# iprec_at_recall_0.20     33      1.0000
# iprec_at_recall_0.30     33      1.0000
# iprec_at_recall_0.40     33      1.0000
# iprec_at_recall_0.50     33      1.0000
# iprec_at_recall_0.60     33      1.0000
# iprec_at_recall_0.70     33      1.0000
# iprec_at_recall_0.80     33      1.0000
# iprec_at_recall_0.90     33      1.0000
# iprec_at_recall_1.00     33      1.0000
# P_5                      33      0.2000
# P_10                     33      0.1000
# P_15                     33      0.0667
# P_20                     33      0.0500
# P_30                     33      0.0333
# P_100                    33      0.0100
# P_200                    33      0.0050
# P_500                    33      0.0020
# P_1000                   33      0.0010
# relstring                33      0.0000
# recall_5                 33      1.0000
# recall_10                33      1.0000
# recall_15                33      1.0000
# recall_20                33      1.0000
# recall_30                33      1.0000
# recall_100               33      1.0000
# recall_200               33      1.0000
# recall_500               33      1.0000
# recall_1000              33      1.0000
# infAP                    33      1.0000
# gm_bpref                 33      0.0000
# Rprec_mult_0.20          33      1.0000
# Rprec_mult_0.40          33      1.0000
# Rprec_mult_0.60          33      1.0000
# Rprec_mult_0.80          33      1.0000
# Rprec_mult_1.00          33      1.0000
# Rprec_mult_1.20          33      0.5000
# Rprec_mult_1.40          33      0.5000
# Rprec_mult_1.60          33      0.5000
# Rprec_mult_1.80          33      0.5000
# Rprec_mult_2.00          33      0.5000
# utility                  33      -667.0000
# 11pt_avg                 33      1.0000
# binG                     33      1.0000
# G                        33      1.0000
# ndcg                     33      1.0000
# ndcg_rel                 33      1.0000
# Rndcg                    33      1.0000
# ndcg_cut_5               33      1.0000
# ndcg_cut_10              33      1.0000
# ndcg_cut_15              33      1.0000
# ndcg_cut_20              33      1.0000
# ndcg_cut_30              33      1.0000
# ndcg_cut_100             33      1.0000
# ndcg_cut_200             33      1.0000
# ndcg_cut_500             33      1.0000
# ndcg_cut_1000            33      1.0000
# map_cut_5                33      1.0000
# map_cut_10               33      1.0000
# map_cut_15               33      1.0000
# map_cut_20               33      1.0000
# map_cut_30               33      1.0000
# map_cut_100              33      1.0000
# map_cut_200              33      1.0000
# map_cut_500              33      1.0000
# map_cut_1000             33      1.0000
# relative_P_5             33      1.0000
# relative_P_10            33      1.0000
# relative_P_15            33      1.0000
# relative_P_20            33      1.0000
# relative_P_30            33      1.0000
# relative_P_100           33      1.0000
# relative_P_200           33      1.0000
# relative_P_500           33      1.0000
# relative_P_1000          33      1.0000
# success_1                33      1.0000
# success_5                33      1.0000
# success_10               33      1.0000
# set_P                    33      0.0015
# set_relative_P           33      1.0000
# set_recall               33      1.0000
# set_map                  33      0.0015
# set_F                    33      0.0030
# num_nonrel_judged_ret    33      69.0000
# num_q                    36      1.0000
# num_ret                  36      323.0000
# num_rel                  36      3.0000
# num_rel_ret              36      1.0000
# map                      36      0.0030
# gm_map                   36      -5.7991
# Rprec                    36      0.0000
# bpref                    36      0.0000
# recip_rank               36      0.0091
# iprec_at_recall_0.00     36      0.0091
# iprec_at_recall_0.10     36      0.0091
# iprec_at_recall_0.20     36      0.0091
# iprec_at_recall_0.30     36      0.0091
# iprec_at_recall_0.40     36      0.0000
# iprec_at_recall_0.50     36      0.0000
# iprec_at_recall_0.60     36      0.0000
# iprec_at_recall_0.70     36      0.0000
# iprec_at_recall_0.80     36      0.0000
# iprec_at_recall_0.90     36      0.0000
# iprec_at_recall_1.00     36      0.0000
# P_5                      36      0.0000
# P_10                     36      0.0000
# P_15                     36      0.0000
# P_20                     36      0.0000
# P_30                     36      0.0000
# P_100                    36      0.0000
# P_200                    36      0.0050
# P_500                    36      0.0020
# P_1000                   36      0.0010
# relstring                36      0.0000
# recall_5                 36      0.0000
# recall_10                36      0.0000
# recall_15                36      0.0000
# recall_20                36      0.0000
# recall_30                36      0.0000
# recall_100               36      0.0000
# recall_200               36      0.3333
# recall_500               36      0.3333
# recall_1000              36      0.3333
# infAP                    36      0.0030
# gm_bpref                 36      -11.5129
# Rprec_mult_0.20          36      0.0000
# Rprec_mult_0.40          36      0.0000
# Rprec_mult_0.60          36      0.0000
# Rprec_mult_0.80          36      0.0000
# Rprec_mult_1.00          36      0.0000
# Rprec_mult_1.20          36      0.0000
# Rprec_mult_1.40          36      0.0000
# Rprec_mult_1.60          36      0.0000
# Rprec_mult_1.80          36      0.0000
# Rprec_mult_2.00          36      0.0000
# utility                  36      -321.0000
# 11pt_avg                 36      0.0033
# binG                     36      0.0491
# G                        36      0.0491
# ndcg                     36      0.0691
# ndcg_rel                 36      0.0691
# Rndcg                    36      0.0345
# ndcg_cut_5               36      0.0000
# ndcg_cut_10              36      0.0000
# ndcg_cut_15              36      0.0000
# ndcg_cut_20              36      0.0000
# ndcg_cut_30              36      0.0000
# ndcg_cut_100             36      0.0000
# ndcg_cut_200             36      0.0691
# ndcg_cut_500             36      0.0691
# ndcg_cut_1000            36      0.0691
# map_cut_5                36      0.0000
# map_cut_10               36      0.0000
# map_cut_15               36      0.0000
# map_cut_20               36      0.0000
# map_cut_30               36      0.0000
# map_cut_100              36      0.0000
# map_cut_200              36      0.0030
# map_cut_500              36      0.0030
# map_cut_1000             36      0.0030
# relative_P_5             36      0.0000
# relative_P_10            36      0.0000
# relative_P_15            36      0.0000
# relative_P_20            36      0.0000
# relative_P_30            36      0.0000
# relative_P_100           36      0.0000
# relative_P_200           36      0.3333
# relative_P_500           36      0.3333
# relative_P_1000          36      0.3333
# success_1                36      0.0000
# success_5                36      0.0000
# success_10               36      0.0000
# set_P                    36      0.0031
# set_relative_P           36      0.3333
# set_recall               36      0.3333
# set_map                  36      0.0010
# set_F                    36      0.0061
# num_nonrel_judged_ret    36      21.0000
# num_q                    43      1.0000
# num_ret                  43      233.0000
# num_rel                  43      1.0000
# num_rel_ret              43      1.0000
# map                      43      0.0588
# gm_map                   43      -2.8332
# Rprec                    43      0.0000
# bpref                    43      0.0000
# recip_rank               43      0.0588
# iprec_at_recall_0.00     43      0.0588
# iprec_at_recall_0.10     43      0.0588
# iprec_at_recall_0.20     43      0.0588
# iprec_at_recall_0.30     43      0.0588
# iprec_at_recall_0.40     43      0.0588
# iprec_at_recall_0.50     43      0.0588
# iprec_at_recall_0.60     43      0.0588
# iprec_at_recall_0.70     43      0.0588
# iprec_at_recall_0.80     43      0.0588
# iprec_at_recall_0.90     43      0.0588
# iprec_at_recall_1.00     43      0.0588
# P_5                      43      0.0000
# P_10                     43      0.0000
# P_15                     43      0.0000
# P_20                     43      0.0500
# P_30                     43      0.0333
# P_100                    43      0.0100
# P_200                    43      0.0050
# P_500                    43      0.0020
# P_1000                   43      0.0010
# relstring                43      0.0000
# recall_5                 43      0.0000
# recall_10                43      0.0000
# recall_15                43      0.0000
# recall_20                43      1.0000
# recall_30                43      1.0000
# recall_100               43      1.0000
# recall_200               43      1.0000
# recall_500               43      1.0000
# recall_1000              43      1.0000
# infAP                    43      0.0588
# gm_bpref                 43      -11.5129
# Rprec_mult_0.20          43      0.0000
# Rprec_mult_0.40          43      0.0000
# Rprec_mult_0.60          43      0.0000
# Rprec_mult_0.80          43      0.0000
# Rprec_mult_1.00          43      0.0000
# Rprec_mult_1.20          43      0.0000
# Rprec_mult_1.40          43      0.0000
# Rprec_mult_1.60          43      0.0000
# Rprec_mult_1.80          43      0.0000
# Rprec_mult_2.00          43      0.0000
# utility                  43      -231.0000
# 11pt_avg                 43      0.0588
# binG                     43      0.2398
# G                        43      0.2398
# ndcg                     43      0.2398
# ndcg_rel                 43      0.2398
# Rndcg                    43      0.1199
# ndcg_cut_5               43      0.0000
# ndcg_cut_10              43      0.0000
# ndcg_cut_15              43      0.0000
# ndcg_cut_20              43      0.2398
# ndcg_cut_30              43      0.2398
# ndcg_cut_100             43      0.2398
# ndcg_cut_200             43      0.2398
# ndcg_cut_500             43      0.2398
# ndcg_cut_1000            43      0.2398
# map_cut_5                43      0.0000
# map_cut_10               43      0.0000
# map_cut_15               43      0.0000
# map_cut_20               43      0.0588
# map_cut_30               43      0.0588
# map_cut_100              43      0.0588
# map_cut_200              43      0.0588
# map_cut_500              43      0.0588
# map_cut_1000             43      0.0588
# relative_P_5             43      0.0000
# relative_P_10            43      0.0000
# relative_P_15            43      0.0000
# relative_P_20            43      1.0000
# relative_P_30            43      1.0000
# relative_P_100           43      1.0000
# relative_P_200           43      1.0000
# relative_P_500           43      1.0000
# relative_P_1000          43      1.0000
# success_1                43      0.0000
# success_5                43      0.0000
# success_10               43      0.0000
# set_P                    43      0.0043
# set_relative_P           43      1.0000
# set_recall               43      1.0000
# set_map                  43      0.0043
# set_F                    43      0.0085
# num_nonrel_judged_ret    43      21.0000
# num_q                    47      1.0000
# num_ret                  47      580.0000
# num_rel                  47      1.0000
# num_rel_ret              47      1.0000
# map                      47      1.0000
# gm_map                   47      0.0000
# Rprec                    47      1.0000
# bpref                    47      1.0000
# recip_rank               47      1.0000
# iprec_at_recall_0.00     47      1.0000
# iprec_at_recall_0.10     47      1.0000
# iprec_at_recall_0.20     47      1.0000
# iprec_at_recall_0.30     47      1.0000
# iprec_at_recall_0.40     47      1.0000
# iprec_at_recall_0.50     47      1.0000
# iprec_at_recall_0.60     47      1.0000
# iprec_at_recall_0.70     47      1.0000
# iprec_at_recall_0.80     47      1.0000
# iprec_at_recall_0.90     47      1.0000
# iprec_at_recall_1.00     47      1.0000
# P_5                      47      0.2000
# P_10                     47      0.1000
# P_15                     47      0.0667
# P_20                     47      0.0500
# P_30                     47      0.0333
# P_100                    47      0.0100
# P_200                    47      0.0050
# P_500                    47      0.0020
# P_1000                   47      0.0010
# relstring                47      0.0000
# recall_5                 47      1.0000
# recall_10                47      1.0000
# recall_15                47      1.0000
# recall_20                47      1.0000
# recall_30                47      1.0000
# recall_100               47      1.0000
# recall_200               47      1.0000
# recall_500               47      1.0000
# recall_1000              47      1.0000
# infAP                    47      1.0000
# gm_bpref                 47      0.0000
# Rprec_mult_0.20          47      1.0000
# Rprec_mult_0.40          47      1.0000
# Rprec_mult_0.60          47      1.0000
# Rprec_mult_0.80          47      1.0000
# Rprec_mult_1.00          47      1.0000
# Rprec_mult_1.20          47      0.5000
# Rprec_mult_1.40          47      0.5000
# Rprec_mult_1.60          47      0.5000
# Rprec_mult_1.80          47      0.5000
# Rprec_mult_2.00          47      0.5000
# utility                  47      -578.0000
# 11pt_avg                 47      1.0000
# binG                     47      1.0000
# G                        47      1.0000
# ndcg                     47      1.0000
# ndcg_rel                 47      1.0000
# Rndcg                    47      1.0000
# ndcg_cut_5               47      1.0000
# ndcg_cut_10              47      1.0000
# ndcg_cut_15              47      1.0000
# ndcg_cut_20              47      1.0000
# ndcg_cut_30              47      1.0000
# ndcg_cut_100             47      1.0000
# ndcg_cut_200             47      1.0000
# ndcg_cut_500             47      1.0000
# ndcg_cut_1000            47      1.0000
# map_cut_5                47      1.0000
# map_cut_10               47      1.0000
# map_cut_15               47      1.0000
# map_cut_20               47      1.0000
# map_cut_30               47      1.0000
# map_cut_100              47      1.0000
# map_cut_200              47      1.0000
# map_cut_500              47      1.0000
# map_cut_1000             47      1.0000
# relative_P_5             47      1.0000
# relative_P_10            47      1.0000
# relative_P_15            47      1.0000
# relative_P_20            47      1.0000
# relative_P_30            47      1.0000
# relative_P_100           47      1.0000
# relative_P_200           47      1.0000
# relative_P_500           47      1.0000
# relative_P_1000          47      1.0000
# success_1                47      1.0000
# success_5                47      1.0000
# success_10               47      1.0000
# set_P                    47      0.0017
# set_relative_P           47      1.0000
# set_recall               47      1.0000
# set_map                  47      0.0017
# set_F                    47      0.0034
# num_nonrel_judged_ret    47      41.0000
# num_q                    all     14.0000
# num_ret                  all     8020.0000
# num_rel                  all     31.0000
# num_rel_ret              all     26.0000
# map                      all     0.3761
# gm_map                   all     0.1408
# Rprec                    all     0.3304
# bpref                    all     0.3304
# recip_rank               all     0.4694
# iprec_at_recall_0.00     all     0.4813
# iprec_at_recall_0.10     all     0.4813
# iprec_at_recall_0.20     all     0.4153
# iprec_at_recall_0.30     all     0.4134
# iprec_at_recall_0.40     all     0.4074
# iprec_at_recall_0.50     all     0.4074
# iprec_at_recall_0.60     all     0.3410
# iprec_at_recall_0.70     all     0.3335
# iprec_at_recall_0.80     all     0.3335
# iprec_at_recall_0.90     all     0.3335
# iprec_at_recall_1.00     all     0.3335
# P_5                      all     0.0857
# P_10                     all     0.0643
# P_15                     all     0.0429
# P_20                     all     0.0429
# P_30                     all     0.0381
# P_100                    all     0.0171
# P_200                    all     0.0093
# P_500                    all     0.0037
# P_1000                   all     0.0019
# relstring                all     0.0000
# recall_5                 all     0.3304
# recall_10                all     0.4256
# recall_15                all     0.4256
# recall_20                all     0.5827
# recall_30                all     0.7131
# recall_100               all     0.8875
# recall_200               all     0.9256
# recall_500               all     0.9256
# recall_1000              all     0.9256
# infAP                    all     0.3761
# gm_bpref                 all     0.0011
# Rprec_mult_0.20          all     0.3929
# Rprec_mult_0.40          all     0.3750
# Rprec_mult_0.60          all     0.3357
# Rprec_mult_0.80          all     0.3316
# Rprec_mult_1.00          all     0.3304
# Rprec_mult_1.20          all     0.1738
# Rprec_mult_1.40          all     0.1726
# Rprec_mult_1.60          all     0.1662
# Rprec_mult_1.80          all     0.1774
# Rprec_mult_2.00          all     0.1771
# utility                  all     -569.1429
# 11pt_avg                 all     0.3892
# binG                     all     0.4668
# G                        all     0.4668
# ndcg                     all     0.5143
# ndcg_rel                 all     0.5048
# Rndcg                    all     0.4309
# ndcg_cut_5               all     0.3537
# ndcg_cut_10              all     0.3897
# ndcg_cut_15              all     0.3897
# ndcg_cut_20              all     0.4295
# ndcg_cut_30              all     0.4622
# ndcg_cut_100             all     0.5058
# ndcg_cut_200             all     0.5143
# ndcg_cut_500             all     0.5143
# ndcg_cut_1000            all     0.5143
# map_cut_5                all     0.3304
# map_cut_10               all     0.3505
# map_cut_15               all     0.3505
# map_cut_20               all     0.3596
# map_cut_30               all     0.3665
# map_cut_100              all     0.3753
# map_cut_200              all     0.3761
# map_cut_500              all     0.3761
# map_cut_1000             all     0.3761
# relative_P_5             all     0.3357
# relative_P_10            all     0.4256
# relative_P_15            all     0.4256
# relative_P_20            all     0.5827
# relative_P_30            all     0.7131
# relative_P_100           all     0.8875
# relative_P_200           all     0.9256
# relative_P_500           all     0.9256
# relative_P_1000          all     0.9256
# success_1                all     0.4286
# success_5                all     0.4286
# success_10               all     0.5714
# set_P                    all     0.0085
# set_relative_P           all     0.9256
# set_recall               all     0.9256
# set_map                  all     0.0078
# set_F                    all     0.0167
# num_nonrel_judged_ret    all     1041.0000

# %%
q3.print_rel_name('1')
# Out:
# ---------------------------Topic_id and Topic_phrase----------------------------------
#
# 1 Q0 G00-73-3287750 461 1.012150 test
# 1 Q0 G00-84-0274223 462 0.992667 test
# 1 Q0 G00-78-2551063 463 0.903357 test
# 1 Q0 G00-74-1394517 464 0.900341 test
# 1 Q0 G00-87-1292162 465 0.857826 test
# 1 Q0 G00-23-3770912 466 0.766363 test
# 1 Q0 G00-89-0106321 467 0.753040 test
# 1 Q0 G00-33-2857182 468 0.697770 test
# 1 Q0 G00-75-3743073 469 0.658111 test
# 1 Q0 G00-93-3473671 470 0.644872 test
# 1 Q0 G00-87-3746944 471 0.590748 test
# 1 Q0 G00-33-2347653 472 0.524853 test
# 1 Q0 G00-24-3625720 473 0.494483 test
# 1 Q0 G00-60-0631416 474 0.479933 test
# 1 Q0 G00-58-1033990 475 0.438552 test
# 1 Q0 G00-47-1352318 476 0.438552 test
# 1 Q0 G00-25-1928405 477 0.400453 test
# 1 Q0 G00-18-2154531 478 0.400453 test
# 1 Q0 G00-32-3296216 479 0.400453 test
# 1 Q0 G00-28-0286112 480 0.354506 test
# ---------------------------Relevant documents----------------------------------
# 1 0 G00-00-1006224 1
# 1 0 G00-02-0901987 1
# 1 0 G00-03-1898526 1
# 1 0 G00-10-3730888 1
# 1 0 G00-10-3849661 1

# %% [markdown]
# ### Q3 (c): Provide answer to Q3 (c) here [markdown cell]
#
# Added analyzers: LowercaseFilter, IntraWordFilter, StopFilter and a lemmatizer of Lancaster that serve as a stemFilter. In addition, the query group was changed from AND to OrGroup.
#
# There was an overall increase in the MAP score. It rised from 0.2365 to 0.3761. In the new IR object, more documents are being returned in the boolean retrieval stage leading to decrease in the False Negatives. Yet, there was a huge increase in False Postives since many documents though contains some query words but are totally inrelevant to the query info need.

# %% [markdown]
# ### Q3 (d): Provide answer to Q3 (d) here [markdown cell]
#
# Yes

# %% [markdown]
# ### Q3 (e): Provide answer to Q3 (e) here [markdown cell]
#
# Query 22, 26 has drop in terms of MAP score while others has increased or remain the same if it is already a 1.

# %% [markdown]
# ### Q3 (f): Provide answer to Q3 (f) here [markdown cell]
#
# It looks like there are some positive improvements. Because there is an overall increase in MAP score. In addition, the number of false negatives has decreased dramatically due to the OrGroup in the query searcher. What is more, because our vanilla whoosh previously was so primitive that most of the query has a map score of 0 indicating it cannot find the "right" document at all, even though the recall was very poor in our new model it is still better than our old one.

# %% [markdown]
# ## Validation

# %%
# Run the following cells to make sure your code returns the correct value types

# %%
from whoosh.index import FileIndex
from whoosh.qparser import QueryParser
from whoosh.searching import Searcher
import os.path

# %% [markdown]
# ### Q2 Validation

# %%
q2 = IRQ2("government")
assert(isinstance(q2.index_sys, FileIndex)), "Index Type"
assert(isinstance(q2.query_parser, QueryParser)), "Query Parser Type"
assert(isinstance(q2.searcher, Searcher)), "Searcher Type"
print("Q2 Types Validated")
# Out:
# Q2 Types Validated

# %% [markdown]
# ### Q3 Validation

# %%
q3 = IRQ3("government")
assert(isinstance(q3.index_sys, FileIndex)), "Index Type"
assert(isinstance(q3.query_parser, QueryParser)), "Query Parser Type"
assert(isinstance(q3.searcher, Searcher)), "Searcher Type"
print("Q3 Types Validated")
# Out:
# Q3 Types Validated
